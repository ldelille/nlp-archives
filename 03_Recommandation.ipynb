# %% [markdown]
# # Demo notebook for article recommandation
#
# The goal of this notebook is to show a typical recommandation workflow, as it will be performed through the chatbot.
#
# Here we only demonstrate the use of the pretrained models and explore some ways of personnalizing the recommandation.
#
#
# ### Contents
#
# __Preliminaries__
# * a. Package Imports
# * b. Data and models
#
# __1. Geo & Topic prediction__
#
# * Prediction of input article's geographic zone and topic
#
# __2. Basic reco based on article body similarity__
#
# * a. Most similar article
#
# * b. Random articles from the same cluster
#
# __3. Similarity-based reco with filter on geo and topic__
#
# __4. How to use the title__
#
# __5. Entity-based recommandation__

# %% [markdown]
# ### Preliminaries [ to do : clean imports]

# %% [markdown]
# A. Packages

# %%
## Classic packages ##

import os 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter
import random 
random.seed(a=2905) # set random seed 
from random import choices
import pickle
import re
from scipy import stats
from time import time

## NLP packages ##

import gensim
from gensim import corpora

from wordcloud import WordCloud

import spacy
try: 
    print("fr_core_news_sm loaded")
    nlp = spacy.load("fr_core_news_sm") # load pre-trained models for French
except:
    print("fr loaded")
    nlp=spacy.load('fr') # fr calls fr_core_news_sm 
from spacy.lang.fr import French

import nltk
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer # not adapted to French?
from nltk.stem.snowball import FrenchStemmer # already something 

## ML with sklearn ##

from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer, TfidfVectorizer 

from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC, SVC
import sklearn.cluster
from sklearn.cluster import KMeans
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, StratifiedShuffleSplit
from sklearn.model_selection import cross_val_score, cross_validate

from sklearn.base import TransformerMixin
from sklearn.compose import make_column_selector

from sklearn.metrics import classification_report
from sklearn.metrics import silhouette_score
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# fr_core_news_sm loaded

# %% [markdown]
# B. Data and models
#
# * Dataset with Past articles = our database for article recommandation
#
# * User input = some recent article manually picked on the Internet
#
# We need:
#
# * tfidf model to transform the article body --> saved pipeline
# * models for geo and topic classification --> saved pipeline
# * cosine distance for basic comparison --> python
# * kmeans model for clustering --> still to save

# %%
# Kmeans and corresponding tfidf

"""
with open('tfidf_vectorizer_base', 'rb') as file:
    tfidf_vectorizer_base = pickle.load(file)

with open('tfidf_vectorizer_vocab', 'rb') as file:
    tfidf_vectorizer_vocab = pickle.load(file)
"""

with open('tfidf_vectorizer_vocab_LOC', 'rb') as file:
    tfidf_vectorizer_vocab_LOC = pickle.load(file)

with open('kmeans_vocab_LOC', 'rb') as file:
    kmeans_vocab_LOC = pickle.load(file)

# %%
# Load pipelines from saved pickle files


with open('best_topic_lr_basic_vocab', 'rb') as file:
    best_topic_lr_basic_vocab = pickle.load(file)

with open('best_topic_lr_basic_vocab_l2', 'rb') as file:
    best_topic_lr_basic_vocab_l2 = pickle.load(file)
    
with open('best_topic_rf_basic_vocab', 'rb') as file:
    best_topic_rf_basic_vocab = pickle.load(file)

with open('best_geo_rf_entity_vocab', 'rb') as file:
    best_geo_rf_entity_vocab = pickle.load(file)

# %%
# topic codes

with open('geo_code_dic', 'rb') as file:
    geo_code_dic = pickle.load(file)
    
with open('topic_code_dic', 'rb') as file:
    topic_code_dic = pickle.load(file)
    
print(geo_code_dic)
print(topic_code_dic)
# Out:
# {0: 'afr', 1: 'as', 2: 'eu', 3: 'fr', 4: 'lat', 5: 'me', 6: 'spa', 7: 'usa', 8: 'wo'}
# {0: 'cu', 1: 'eco', 2: 'ju', 3: 'mi', 4: 'po', 5: 'sc', 6: 'so', 7: 'spo'}

# %%
labeled_df=pd.read_csv("labeled_articles_clean.csv")
labeled_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  year                              title  \
# 0           0             0  1988               Tintin dans l'espace
# 1           1             1  1988   Le faux suicide de Robert Boulin
# 2           2             2  1988  Des pierres contre les certitudes
# 3           3             3  1988  Otages: soudain, mercredi soir...
# 4           4             4  1988    Les secrets de la planète rouge
#
#                                                 text  \
# 0  Trois semaines à bord de la station soviétique...
# 1  1979 : son corps est découvert en forêt de Ram...
# 2  Rideaux de fer baissés, silhouettes furtives, ...
# 3  " Je lui ai dit: "Ça suffit", et j'ai raccroch...
# 4  S'il existe, dans le système solaire, un seul ...
#
#                                                  url  geo topic  \
# 0  https://www.lexpress.fr/informations/tintin-da...   fr    sc
# 1  https://www.lexpress.fr/actualite/politique/le...   fr    ju
# 2  https://www.lexpress.fr/actualite/monde/proche...   me    po
# 3  https://www.lexpress.fr/informations/otages-so...   me    ju
# 4  https://www.lexpress.fr/actualite/sciences/les...  spa    sc
#
#                                           clean_text  \
# 0  semain bord station soviet jean-loup chrétien ...
# 1  corp découvert forêt rambouillet fauss pist né...
# 2  rideau baiss silhouet furtiv jérusalem arab to...
# 3  suff raccroch trop souvent échaud trop souvent...
# 4  exist system solair seul endroit exobiolog dés...
#
#                  clean_title                  pre_title  \
# 0               tintin espac               tintin espac
# 1  faux suicid robert boulin  faux suicid robert boulin
# 2       pierr contr certitud       pierr contr certitud
# 3  otag soudain mercred soir  otag soudain mercred soir
# 4         secret planet roug         secret planet roug
#
#                                             pre_text  geo_code  topic_code
# 0  semain bord station soviet jean-loup chrétien ...         3           5
# 1  corp découvert forêt rambouillet fauss pist né...         3           2
# 2  rideau baiss silhouet furtiv jérusalem arab to...         5           4
# 3  suff raccroch trop souvent échaud trop souvent...         5           2
# 4  exist system solair seul endroit exobiolog dés...         6           5

# %%
sample_df=pd.read_excel("sample_articles.xlsx")
sample_df.head(20)
# Out:
#                                                 title  \
# 0   « L’Ickabog », de J. K. Rowling : le triste ro...
# 1   Covid-19 en France : Jean Castex expose la str...
# 2   Claude Guéant mis en examen pour « association...
# 3   Pédocriminalité : quinze ans de réclusion requ...
# 4   Le prix littéraire Interallié décerné à Irène ...
# 5   Les championnats de foot reprennent au Maroc e...
# 6                 Le scandale des employées de maison
# 7         Mosaïque ethnique dans une zone de tensions
# 8   Une population réunie dans la rue contre l’oli...
# 9   Outre-Rhin aussi, médecins et infirmiers dénon...
# 10  Dossier États-Unis : Changement ou restauratio...
# 11  Un rejet exacerbé qui profite aux démagogues. ...
#
#                                                  text  \
# 0   C’est l’histoire d’un conte de fées qui se tra...
# 1   Le premier ministre doit présenter la stratégi...
# 2   L’ex-ministre de l’intérieur était déjà mis en...
# 3   L’homme de 70 ans comparait à huis clos pour r...
# 4   L’autrice, qui raconte les suites du meurtre d...
# 5   Affaiblis économiquement par l’interruption de...
# 6   Originaire d’Asie du Sud-Est et, plus récemmen...
# 7   Selon le chef de la Commission soudanaise des ...
# 8   L’ex-première ministre moldave Maïa Sandu a ba...
# 9   Monsieur Axel Hopfmann a longtemps été infirmi...
# 10  Les premiers choix de M. Joseph Biden pour les...
# 11  Assassinat d’un journaliste trop curieux en Sl...
#
#                                                   url  year  geo topic  \
# 0   https://www.lemonde.fr/livres/article/2020/12/...  2020   eu    cu
# 1   https://www.lemonde.fr/planete/article/2020/12...  2020   fr    po
# 2   https://www.lemonde.fr/societe/article/2020/12...  2020   fr    ju
# 3   https://www.lemonde.fr/societe/article/2020/12...  2020   fr    ju
# 4   https://www.lemonde.fr/culture/article/2020/12...  2020   fr    cu
# 5   https://www.lemonde.fr/afrique/article/2020/12...  2020  afr   spo
# 6   https://www.monde-diplomatique.fr/mav/174/LAUR...  2020   me    so
# 7   https://www.monde-diplomatique.fr/cartes/mosai...  2020  afr    po
# 8   https://www.monde-diplomatique.fr/2016/10/BEUR...  2020   eu    po
# 9   https://www.monde-diplomatique.fr/2020/09/KNAE...  2020   eu    so
# 10  https://www.monde-diplomatique.fr/2020/12/HALI...  2020  usa    po
# 11  https://www.monde-diplomatique.fr/2018/04/CUNN...  2020   eu    po
#
#     geo_code  topic_code
# 0          2           0
# 1          3           4
# 2          3           2
# 3          3           2
# 4          3           0
# 5          0           7
# 6          5           6
# 7          0           4
# 8          2           4
# 9          2           6
# 10         7           4
# 11         2           4

# %% [markdown]
# ## 1. Geo and Topic prediction

# %% [markdown]
# __Preprocessing of texts__

# %%
print(labeled_df.clean_text[0])
# Out:
# semain bord station soviet jean-loup chrétien premi ouest-européen sort espac orgueil survol human mont cerveau certain sien général étoil torch tranquill douzain escargot bourgogn pénich restaur moskov relev gourmandis gorg bordeau potel chabot apprêt quelqu heur transperc voût célest rejoindr station soviet pétard ton allum sous fess plus stress ordinair class jean-loup chrétien sauf incident derni minut auquel remplac doublur michel tognin premi spationaut ouest-européen effectu mission longu dur semain march vid spatial voilà vibr fibr cocardi revigor moral armé trop souvent dérout quinquagénair champion espac affich san moll machin fait bav aucun raison ménag beau bigeard petit jeunot piétinent port centrifug caisson altitud tabouret tourn autr supplic initiat devront patient rejoindr confrer élus elus chanceux rien plus temp grison trait fin modest naturel chrétien jou antihéros ceux fantasment looping chuck yeag glorieux retour façon john glen gagarin changent chaîn tromp film préfer cultiv genr meilleur ouvri franc son plus honnêt oreil breton réuss oubli aviat chass essai soviet sélection repris travaill point aujourd' don tout naturel décrisp est-ouest amis russ plus épous américain rencontr houston pend entraîn franc ingrat incoll composit équip rugby spationaut débrouillent confondr fais port chrétien déplor béret basqu dont patrick baudry affubl bord discovery attribu derni titr premi européen espac revient chrétien fois encor risqu frais innov allon sponsoris lâch constern orgueil catamaran taill sous nom choucrout boît peut craindr pir conquer espac transform voyageur commerc griff demi-gros étoff héros vrai sert chrétien décarc dorm accroch plafond réduir espac club amateur nouvel aut plus saumâtr entraîn plus grand rigueur cit étoil cosmonaut vivent vas clos proteg tout pourr affaibl déstabilis murmur juillet derni bien tout envoi vals retrouv bretagn natal fait pass temp prépar mission loin fil drôl tendu ver départ simpl entors peut remettr question pourquoi argent spationaut cne gagn plus ingénieur détach environ franc plus prim attribu tout pilot mag spectacl sourir émerveil vient plus facil mirag sang pilot saur ment rien vaut affirment -il tous envoi mach maîtr absolu appareil rest attrait inconnu conduit véhicul permanent chut libr autour terr quoiqu écout haut tres surfait nourr plat réchauff flott espac metr tres vit cosmonaut commencent trac croix calendri homm surentraîn doivent rompus seul ergonom astronom mathémat auss disciplin ménager question balanc container ordur import espac sinon gar collis station prochain tour orbital détendr autour entre copain alcool bord interd ailleur flott grapp bull sous tel ingrat guet aspir voyageur espac rêv mirag chrétien retrouv respons essais adjoint chef divis défens aérien rest pilot chass veut toujour pilot avion plus vit puis quelqu chos plus ail plus avion plus haut evoqu mort rétract oeil bleu scandalis brutal question vol prend risqu sobr preuv seul fois faill crash bretagn cour balad tourist baudry anatol berezovoï met cosmonaut chevron bord trinidad plac don atterrissag catastroph champ choux fleur jean-loup chrétien rarissim grad avouent amus aim don ordre fait recevoir esprit initi prend rud coup paraît méti tout décid derni vétéran cabriol hor pesanteur devr décid aven saut vid trac bien plus précédent travaill priv haut coeur main kep pens cosmonaut militair défroqu rumeur pressent déjà futur directeur européen vol spatial habit attend prépar baroud honneur làhaut veil noël offrir concert franc orgu électron fait achemin jusqu' station pourr jou devin minuit chrétien évident

# %%
# preprocessing for the sample articles
my_fr_stop = {'celui-ci', 'de', 'serait', 'fussions', 'aux', 'seriez', 'c', 'notre', 'une', 'seraient', 'avons', 'eûmes', 'ayantes', 'sur', 'alors', 'ayons', 'ait', 'du', 'ils', 'serai', 'fussent', 'vingt', 'avais', 'eus', 'eurent', 'm', 'ne', 'fûtes', 'sept', 'neuf', 'fusses', 'la', 'eussiez', 'vos', 'eût', 'te', 'huit', 'aura', 'j', 'étante', 'eut', 'ont', 'elle', 'leur', 'avec', 'ni', 'mais', 'quatre', 'aviez', 'sera', 'tes', 'ayants', 'à', 'soient', 'votre', 'ou', 'y', 'et', 'avions', 'je', 'fusse', 'fût', 'fut', 'd', 'ma', 'ce', 'il', 'étaient', 'par', 'ton', 'donc', 'soyons', 'les', 'sommes', 'ayante', 'dix', 'treize', 'comme', 'aient', 'seront', 'aie', 'eûtes', 'que', 'étais', 'ayez', 'auriez', 'seras', 'eux', 'n', 'vous', 'eussions', 'fûmes', 'ayant', 'deux', 'étiez', 'aurait', 'ai', 'auraient', 'cinquante', 'étions', 'cette', 'avoir', 't', 'nous', 'des', 'cent', 'toi', 'quinze', 'qui', 'sont', 'or', 'suis', 'serons', 'eue', 'au', 'cinq', 'seize', 'quarante', 'me', 'où', 'pour', 'car', 'étant', 'depuis', 'était', 'l', 's', 'même', 'es', 'avait', 'sois', 'le', 'avaient', 'son', 'étés', 'soixante', 'onze', 'être', 'avez', 'aurais', 'auras', 'eusses', 'nos', 'étées', 'étantes', 'furent', 'ainsi', 'ses', 'six', 'autre', 'eues', 'été', 'est', 'aies', 'se', 'celui-là', 'faire', 'soit', 'aurez', 'pas', 'en', 'moi', 'sa', 'on', 'auront', 'êtes', 'trente', 'quoi', 'quatorze', 'douze', 'étée', 'mes', 'serions', 'fussiez', 'après', 'cet', 'mon', 'ta', 'trois', 'soyez', 'étants', 'dans', 'qu', 'as', 'celui', 'eu', 'quand', 'serez', 'lui', 'aurons', 'eusse', 'ces', 'tu', 'eussent', 'fus', 'avant', 'aurions', 'aurai', 'serais', 'un'}

parser = French()
stemmer = FrenchStemmer()

def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif '@' in str(token):
            lda_tokens+=str(token).split('@')
        else:
            lda_tokens.append(token.lower_)
    return [t for t in lda_tokens if len(str(t))>0]

def prepare_text_stem(text):
    """
    Input:
    ------
    text: string, raw text
    
    Output:
    ------
    tokens: list of string, tokenized, filtered and lemmatized words from the input text
    """
    tokens = tokenize(text) # split and lower case
    tokens=[re.sub(r'\b\d+\b', '', token).strip(' ') for token in tokens] # get rid of digits
    tokens = [token for token in tokens if len(token) > 3] # arbitrary length, +get rid of empty strings
    tokens = [token for token in tokens if token not in my_fr_stop] # stopwords
    #print("Remaining tokens : ", tokens)
    tokens = [stemmer.stem(token) for token in tokens] # obtain lemmas
    return tokens  

title_tokens = []
text_tokens = []

## Apply on titles ##

for t in sample_df.title:
    tokens = prepare_text_stem(t)
    title_tokens.append(tokens)
        
## Apply on titles ##

for t in sample_df.text:
    tokens = prepare_text_stem(t)
    text_tokens.append(tokens)

print(sample_df.title[:1])        
print(title_tokens[:1])
print(sample_df.text[:1][:20])  
print(text_tokens[0][:10])

# save the preprocessed text
sample_df["clean_text"]=[' '.join(text_tokens[i]) for i in range(len(text_tokens))]
sample_df["clean_title"]=[' '.join(title_tokens[i]) for i in range(len(title_tokens))]
# Out:
# 0    « L’Ickabog », de J. K. Rowling : le triste ro...
# Name: title, dtype: object
# [['ickabog', 'rowling', 'trist', 'royaum', 'marcheur']]
# 0    C’est l’histoire d’un conte de fées qui se tra...
# Name: text, dtype: object
# ['histoir', 'cont', 'fé', 'transform', 'cont', 'fous', 'jusqu', 'cornucopi', 'royaum', 'auss']

# %%
sample_df.head()
# Out:
#                                                title  \
# 0  « L’Ickabog », de J. K. Rowling : le triste ro...
# 1  Covid-19 en France : Jean Castex expose la str...
# 2  Claude Guéant mis en examen pour « association...
# 3  Pédocriminalité : quinze ans de réclusion requ...
# 4  Le prix littéraire Interallié décerné à Irène ...
#
#                                                 text  \
# 0  C’est l’histoire d’un conte de fées qui se tra...
# 1  Le premier ministre doit présenter la stratégi...
# 2  L’ex-ministre de l’intérieur était déjà mis en...
# 3  L’homme de 70 ans comparait à huis clos pour r...
# 4  L’autrice, qui raconte les suites du meurtre d...
#
#                                                  url  year geo topic  \
# 0  https://www.lemonde.fr/livres/article/2020/12/...  2020  eu    cu
# 1  https://www.lemonde.fr/planete/article/2020/12...  2020  fr    po
# 2  https://www.lemonde.fr/societe/article/2020/12...  2020  fr    ju
# 3  https://www.lemonde.fr/societe/article/2020/12...  2020  fr    ju
# 4  https://www.lemonde.fr/culture/article/2020/12...  2020  fr    cu
#
#    geo_code  topic_code                                         clean_text  \
# 0         2           0  histoir cont fé transform cont fous jusqu corn...
# 1         3           4  premi ministr doit présent strateg gouvern vac...
# 2         3           2  ex-ministr intérieur déjà examen infract dossi...
# 3         3           2  homm compar huis clos répondr accus viol agres...
# 4         3           0  autric racont suit meurtr sœur aîn obtenu voix...
#
#                                          clean_title
# 0              ickabog rowling trist royaum marcheur
# 1  covid- franc jean castex expos strateg gouvern...
# 2  claud gué examen associ malfaiteur affair fina...
# 3  pédocriminal réclus requ contr ex-chirurgien j...
# 4  prix littérair interalli décern iren frain cri...

# %%
target_geo = ['afrique','asie', 'europe', 'france', 'am. latine', 'moyen-orient', 'espace', 'usa', 'monde']
target_topic = ['culture', 'economie', 'judiciaire', 'divers',  'politique', 'sciences', 'societe', 'sport']

# %% [markdown]
# __A. `Geo`__

# %%
pred_geo=best_geo_rf_entity_vocab.predict(sample_df.clean_text)
pred_geo_labels = [geo_code_dic[x] for x in pred_geo]
print(pred_geo_labels)

print(classification_report(sample_df.geo_code,  pred_geo))
# Out:
# ['fr', 'fr', 'fr', 'fr', 'fr', 'fr', 'fr', 'eu', 'fr', 'fr', 'fr', 'fr']
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            2       0.00      0.00      0.00         4
#            3       0.36      1.00      0.53         4
#            5       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.33        12
#    macro avg       0.07      0.20      0.11        12
# weighted avg       0.12      0.33      0.18        12
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 636 out of 636 | elapsed:    0.1s finished
# /Users/eva/.local/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# __B. `Topic`__

# %%
pred_topic = best_topic_lr_basic_vocab.predict(sample_df.clean_text)
pred_topic_labels = [topic_code_dic[x] for x in pred_topic]
print(pred_topic_labels)

print(classification_report(sample_df.topic_code,  pred_topic))
# Out:
# ['eco', 'eco', 'eco', 'eco', 'eco', 'eco', 'eco', 'eco', 'eco', 'eco', 'eco', 'eco']
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       2.0
#            1       0.00      0.00      0.00       0.0
#            2       0.00      0.00      0.00       2.0
#            4       0.00      0.00      0.00       5.0
#            6       0.00      0.00      0.00       2.0
#            7       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00      12.0
#    macro avg       0.00      0.00      0.00      12.0
# weighted avg       0.00      0.00      0.00      12.0
# /Users/eva/.local/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## 2. Basic reco based on article body similarity

# %% [markdown]
# __A. Most similar article with tfidf vectorizer based on 726 articles__

# %%
## more occurate with geo codes ##

def most_similar(sample_articles, archive_articles, transformer=tfidf_vectorizer_base, refit = True):
    """
    Returns the index of the most similar articles
    sample_articles : dataframe, must have "text" col
    archive_articles : idem
    """
    if refit == True : 
        X = transformer.fit_transform(archive_articles.clean_text) # in case not already fitted, easier for testing
    else :
        X = transformer.transform(archive_articles.clean_text)
    sample_X = transformer.transform(sample_articles.clean_text)
    # compute similarity matrix
    sim_matrix = np.array([[cosine_similarity(sample_X[i], X[j]) for i in range(sample_X.shape[0])] for j in range(X.shape[0])])
    sim_matrix=sim_matrix.reshape([sim_matrix.shape[0], sim_matrix.shape[1]])
    reco_matrix = np.argmax(sim_matrix, axis=0)
    print(np.max(sim_matrix, axis=0))
    return reco_matrix

# %%
# tfidf_vectorizer_vocab
reco = most_similar(sample_df, labeled_df, transformer=tfidf_vectorizer_vocab)
for i in range(len(sample_df)):
    print("\n\n **", sample_df.title[i])
    print("\nMost similar article:", labeled_df.title[reco[i]])
    print(labeled_df.text[reco[i]][:300], '...')
# Out:
# [0.38578684 0.72876036 0.43501886 0.62348507 0.         0.
#  0.5609347  0.42733268 0.60199348 0.82103965 0.43735419 0.50142543]
#
#
#  ** « L’Ickabog », de J. K. Rowling : le triste royaume des Marcheurs
#
# Most similar article: Les departements qui creent le plus d emplois suite de la page 122
# LOIRE-ATLANTIQUE (44)
# Nombre de Salariés au 31 décembre 1997 : 270 591
# Taux de chômage au 31 mars 1998 : 14,5 %
# Emplois créés en un an : 7 257 (+ 2,8 %)
# Emplois créés depuis 1990 : 19 945 (+ 8 %)
# La grande distribution, les services aux entreprises et le tourisme (hôtellerie-restauration) tirent les ...
#
#
#  ** Covid-19 en France : Jean Castex expose la stratégie du gouvernement sur les vaccins
#
# Most similar article: Cadres a temps partiel et fiers de l etre
# Le mercredi, Catherine, gérante de placements dans une grande banque, fait de la musique et s'occupe de ses jeunes enfants. Christian, ingénieur chez Siemens-Nixdorf, ne travaille que le lundi, le mercredi et un vendredi sur deux. Le reste de la semaine, il le consacre à un projet personnel de créat ...
#
#
#  ** Claude Guéant mis en examen pour « association de malfaiteurs » dans l’affaire du financement libyen de la campagne de 2007
#
# Most similar article: Histoire du financement du PS (85-89)
# Un homme, la soixantaine enveloppée, sort d'un porche discret du quai des Grands-Augustins. Sous son bras, un paquet joliment emballé de papier fantaisie. Un beau cadeau, en vérité: 5 millions de francs, en coupures de 500 francs. Le porteur du colis s'appelle Gérard Monate, patron d'Urba-Gracco, la ...
#
#
#  ** Pédocriminalité : quinze ans de réclusion requis contre l’ex-chirurgien Joël Le Scouarnec
#
# Most similar article: Yves barraquand armateur pro le barreur prefere de bollore
# Lorsque Yves Barraquand est venu lui proposer de délocaliser le siège social de Delmas, en le transportant de Puteaux au Havre, Vincent Bolloré a d'abord froncé les sourcils. " C'est vrai, j'ai dû le persuader, raconte aujourd'hui le ­ jeune ­ PDG de la filiale maritime du groupe. Mais il s'est lais ...
#
#
#  ** Le prix littéraire Interallié décerné à Irène Frain pour « Un crime sans importance »
#
# Most similar article: Tintin dans l'espace
# Trois semaines à bord de la station soviétique Mir. A 50 ans, Jean-Loup Chrétien sera le premier Ouest-Européen a sortir dans l'espace.
# L'orgueil fou d'avoir survolé l'humanité est monté au cerveau de certains. Pas au sien. Ce général trois étoiles qui vous torche d'un air tranquille sa douzaine d'e ...
#
#
#  ** Les championnats de foot reprennent au Maroc et en Tunisie sur fond de crise sanitaire
#
# Most similar article: Tintin dans l'espace
# Trois semaines à bord de la station soviétique Mir. A 50 ans, Jean-Loup Chrétien sera le premier Ouest-Européen a sortir dans l'espace.
# L'orgueil fou d'avoir survolé l'humanité est monté au cerveau de certains. Pas au sien. Ce général trois étoiles qui vous torche d'un air tranquille sa douzaine d'e ...
#
#
#  ** Le scandale des employées de maison
#
# Most similar article: L'heure des comptes
# Nous ne sommes pas ici en Amérique du Sud. Ce n'est pas aux officiers de choisir leur ministre.» Rebuffade administrée, le 24 septembre, par Ariel Sharon au général Amram Mitzna, venu lui annoncer qu'il souhaitait être mis en congé sans solde tant qu' «Arik» demeurerait ministre de la Défense. Ancie ...
#
#
#  ** Mosaïque ethnique dans une zone de tensions
#
# Most similar article: QUERELLE DE CHIFFRES
# A l'occasion du Forum de L'Expansion, Pierre Bérégovoy a annoncé des mesures en faveur des entreprises, portant sur les modalités de paiement de la TVA. En clair, l'Etat renonce temporairement à ce qu'elles lui avancent de l'argent. Il s'agit de compenser - pour elles - le retard dans la baisse des  ...
#
#
#  ** Une population réunie dans la rue contre l’oligarchie et la corruption : Après le « casse du siècle » en Moldavie
#
# Most similar article: Omc l union europeenne ira unie aux negociations de seattle
# Les quinze états membres de l"Union Européenne sont parvenus vendredi à fixer une position commune ...
# Les quinze états membres de l?Union Européenne sont parvenus vendredi à fixer une position commune pour les négociations à l'OMC (Organisation mondiale du commerce), qui débuteront fin novembre à S ...
#
#
#  ** Outre-Rhin aussi, médecins et infirmiers dénoncent le « diktat de l’économie »  : Des hôpitaux allemands trop rentables
#
# Most similar article: Allemagne l industrie profite des commandes de l etranger
# Les entrées de commandes de l'industrie allemande des machines-outils et des installations ...
# Les entrées de commandes de l'industrie allemande des machines-outils et des installations industrielles ont augmenté de 2% au mois d'octobre en valeur réelle, comparé au même mois de l'an passé. Cette pro ...
#
#
#  ** Dossier États-Unis : Changement ou restauration ? Amère victoire démocrate
#
# Most similar article: Dérapage contrôlé
# La simplicité et la franchise ne sont pas les points forts du président de la Géorgie. Zviad Gamsakhourdia tresse aujourd?hui une couronne de lauriers à Bons Eltsine : « Sa victoire contre les putschistes nous a sauvés, s?exclame-t-il. Nous et toutes les républiques qui veulent l?indépendance. » Réj ...
#
#
#  ** Un rejet exacerbé qui profite aux démagogues. Effets pervers de la lutte anticorruption en Europe centrale
#
# Most similar article: 1982 : "Le double langage sur l'Europe est désastreux"
# L'ex-présidente du Parlement européen dénonce le manque de courage politique des dirigeants européens et décrypte la politique européenne du gouvernement Mauroy.
# L'Express : La Communauté paraît plus que jamais empêtrée dans ses divisions. Faut-il donc désespérer de l'Europe ?
# Simone Veil : Au momen ...

# %%
# tfidf_vectorizer_base
reco = most_similar(sample_df, labeled_df, transformer=tfidf_vectorizer_base)
for i in range(len(sample_df)):
    print("\n\n **", sample_df.title[i])
    print("\nMost similar article:", labeled_df.title[reco[i]])
    print(labeled_df.text[reco[i]][:300], '...')
# Out:
# [0.27289489 0.37335101 0.43526006 0.48182959 0.31227106 0.30773593
#  0.37628813 0.29000577 0.4629674  0.42372009 0.33879372 0.56163954]
#
#
#  ** « L’Ickabog », de J. K. Rowling : le triste royaume des Marcheurs
#
# Most similar article: Le Jurassic Park du communisme
# A chaque instant, il se passe quelque chose au Grand Magasin n° 1... Au c?ur de Pyongyang, capitale de la Corée du Nord, le bâtiment ne désemplit pas. Il se passe quelque chose, certes. Mais quoi? Pas le moindre badaud dehors, sur le grand boulevard: les clients émergent de la bouche du métro et s'e ...
#
#
#  ** Covid-19 en France : Jean Castex expose la stratégie du gouvernement sur les vaccins
#
# Most similar article: L'affaire Boulin
# Un corps à demi enfoncé dans l'eau noire des étangs de Hollande... Robert Boulin. Le suicide du plus ancien ministre du gouvernement prend aussitôt la dimension d'une affaire d'Etat. Albert du Roy explique la tragédie personnelle vécue par Boulin, et ses implications politiques. Elles vont bien au-d ...
#
#
#  ** Claude Guéant mis en examen pour « association de malfaiteurs » dans l’affaire du financement libyen de la campagne de 2007
#
# Most similar article: L'affaire Boulin
# Un corps à demi enfoncé dans l'eau noire des étangs de Hollande... Robert Boulin. Le suicide du plus ancien ministre du gouvernement prend aussitôt la dimension d'une affaire d'Etat. Albert du Roy explique la tragédie personnelle vécue par Boulin, et ses implications politiques. Elles vont bien au-d ...
#
#
#  ** Pédocriminalité : quinze ans de réclusion requis contre l’ex-chirurgien Joël Le Scouarnec
#
# Most similar article: Les cabinets d avocats d affaires passes au crible
# La société française est entrée dans l'ère des contentieux : sans pour autant tomber dans la dérive des Etats-Unis, où personne ne peut plus faire un pas sans en appeler à son lawyer, cette fin de siècle sera en France celle du droit et donc des avocats. La loi du 31 décembre 1990, instituant la nou ...
#
#
#  ** Le prix littéraire Interallié décerné à Irène Frain pour « Un crime sans importance »
#
# Most similar article: Spirituel
# Ils parlent de Dieu Bertrand Révillion La souffrance, la solidarité, la peur, la résistance spirituelle, la vérité intérieure et... Dieu. Il arrive que les stars du monde politico-mé- diatique parlent autrement, oubliant les parts de marché, le cash-flow ou l'Audimat. Mais lorsque le jardin secret d ...
#
#
#  ** Les championnats de foot reprennent au Maroc et en Tunisie sur fond de crise sanitaire
#
# Most similar article: Le japon veut il changer
# La semaine dernière, une délégation du Keidanren (le patronat nippon) est venue prodiguer au gouvernement français et au CNPF des déclarations de bonne volonté et des promesses d'ouverture commerciale. Le thème n'est pas nouveau : dès 1985, le rapport Maekawa préconisait de réorienter la croissance  ...
#
#
#  ** Le scandale des employées de maison
#
# Most similar article: Le génocide de la faim
# Depuis plus de dix ans, la sécheresse ravage le Sahel. Aujourd'hui, les Ethiopiens meurent par milliers. Seul un programme mondial pourrait freiner le désastre.
# A 2 300 mètres d'altitude, un immense plateau entouré de hautes montagnes. Pierres, sables, terres brûlées: tout est gris et brun. Au centr ...
#
#
#  ** Mosaïque ethnique dans une zone de tensions
#
# Most similar article: Algérie: Les jokers de Chadli
# Presque un an après les émeutes, les réformes se font attendre. En changeant de Premier ministre, 1e président abat ses dernières cartes.
# «Rendez-vous le |e 5 octobre»: onze mois après la sanglante explosion de l'automne dernier, les murs d'Alger se couvrent à nouveau d'inquiétants graffiti. Cet été ...
#
#
#  ** Une population réunie dans la rue contre l’oligarchie et la corruption : Après le « casse du siècle » en Moldavie
#
# Most similar article: 1979 : De la Santé à Strasbourg
# Du ministère de la Santé à la présidence de l'Assemblée européenne... Simone Veil entame sa deuxième carrière. Déjà certains demandent : et après "
# Sur un hommage appuyé du chef de l'Etat ? " Nous regretterons votre sourire ! " ? et une poignée de main exceptionnelle, devant les photographes, en hau ...
#
#
#  ** Outre-Rhin aussi, médecins et infirmiers dénoncent le « diktat de l’économie »  : Des hôpitaux allemands trop rentables
#
# Most similar article: Les Tziganes, parias de 1'Europe
# Persécutés en Roumanie, ils demandent asile à l'Allemagne. Mais là non plus on ne veut pas d'eux. Et Bonn a négocié leur rapatriement avec Bucarest. Les Européens de l'Est les disent voleurs, violeurs, buveurs et bagarreurs. Condamnés à l'errance, ils expient la nouvelle peur du Vieux Continent.
# Le  ...
#
#
#  ** Dossier États-Unis : Changement ou restauration ? Amère victoire démocrate
#
# Most similar article: "On est toujours trahi par les siens"
# Votre ami Didier Schuller, en fuite aux Bahamas, vous met en cause dans une interview au Monde. Il affirme que, en tant que président de l'office HLM des Hauts-de-Seine, c'est vous qui aviez tous les pouvoirs. Il déclare également que vous l'auriez incité à partir, à «prendre du recul», dit-il, et q ...
#
#
#  ** Un rejet exacerbé qui profite aux démagogues. Effets pervers de la lutte anticorruption en Europe centrale
#
# Most similar article: Les Français au bord de l'Europe
# C'est une étrange aventure qui arrive aux Français: au moment même où ils cherchent à s'isoler, à abriter une vie quiète, perdant tout désir d'expansion, tout esprit de mission salvatrice, les voilà nantis d'une étrange invitation non à table, mais à un chantier.
# Et c'est très vite le désarroi, car  ...

# %% [markdown]
# __B. Random articles from the same cluster__
#
# to add ==> save a kmeans model from nbk 02

# %%
X_LOC = tfidf_vectorizer_vocab_LOC.transform(labeled_df.clean_text)
X_sample_LOC = tfidf_vectorizer_vocab_LOC.transform(sample_df.clean_text)

pred_ref_clusters = kmeans_vocab_LOC.predict(X_LOC)
pred_sample_cluster = kmeans_vocab_LOC.predict(X_sample_LOC)

print(pred_sample_cluster)

for i in range(len(sample_df)):
    sample_article = sample_df[sample_df.index==i] # df
    print("\n\n **", sample_df.title[i])
    cluster_i = pred_sample_cluster[i]
    index = pred_ref_clusters==cluster_i
    #print(type(index))
    #print(index[:5])
    filtered_df_i = labeled_df[index]
    #print(len(filtered_df_i))
    #print(filtered_df_i[:5])
    #print(filtered_df_i.index)
    reco_i = choices(filtered_df_i.index, k=3)
    print("Recommandations: ")
    for r in reco_i:
        print(filtered_df_i[filtered_df_i.index==r].title.iloc[0])
# Out:
# [10  7 10  9 10 10  8 10  4  0 11  4]
#
#
#  ** « L’Ickabog », de J. K. Rowling : le triste royaume des Marcheurs
# Recommandations:
# Les troubles encheres du foot francais
# Le ronflement
# Un micro dans le ballon de foot
#
#
#  ** Covid-19 en France : Jean Castex expose la stratégie du gouvernement sur les vaccins
# Recommandations:
# Lvmh s offre les bijoux chaumet et les horloges ebel
# CSG, ton univers impitoyable
# 1966: la crise avec les Américains
#
#
#  ** Claude Guéant mis en examen pour « association de malfaiteurs » dans l’affaire du financement libyen de la campagne de 2007
# Recommandations:
# Directrice trois jours par semaine
# La victoire du c?ur
# Revivre à Kangaroo Island
#
#
#  ** Pédocriminalité : quinze ans de réclusion requis contre l’ex-chirurgien Joël Le Scouarnec
# Recommandations:
# Bouygues bollore le climat se deteriore
# Modes de vie: Temps libre
# Pierre joxe invoque balladur pour contrer chirac
#
#
#  ** Le prix littéraire Interallié décerné à Irène Frain pour « Un crime sans importance »
# Recommandations:
# (Octobre 1990) Pakistan: une femme face aux fusils
# Zapper - Les émissions cette semaine
# Les rescapés du "Santa Rita"
#
#
#  ** Les championnats de foot reprennent au Maroc et en Tunisie sur fond de crise sanitaire
# Recommandations:
# Concerts virtuels
# Les Mad Max de l'Etat sauvage
# L'affaire Boulin
#
#
#  ** Le scandale des employées de maison
# Recommandations:
# Cinéma - Grains de sable
# Otages: soudain, mercredi soir...
# L'ombre sur la campagne
#
#
#  ** Mosaïque ethnique dans une zone de tensions
# Recommandations:
# Guide PARIS - Quand la ville dort - LE JAZZ EST LÀ
# Terre de Feu, mer de sang
# La course contre la mort
#
#
#  ** Une population réunie dans la rue contre l’oligarchie et la corruption : Après le « casse du siècle » en Moldavie
# Recommandations:
# Otan: drame avec qui ?
# JANINA OCHOJSKA - La pédagogie de l'humanitaire
# Vrais et faux modèles
#
#
#  ** Outre-Rhin aussi, médecins et infirmiers dénoncent le « diktat de l’économie »  : Des hôpitaux allemands trop rentables
# Recommandations:
# Theo waigel conseillera alcatel
# "Nord", par L.-F. Céline
# Sous la botte, le cinéma français
#
#
#  ** Dossier États-Unis : Changement ou restauration ? Amère victoire démocrate
# Recommandations:
# Des astres
# Des astres
# Express Santé
#
#
#  ** Un rejet exacerbé qui profite aux démagogues. Effets pervers de la lutte anticorruption en Europe centrale
# Recommandations:
# LE BOIS SE MET AU VERT
# Expatriez vous qu ils disaient
# 1979 : De la Santé à Strasbourg

# %% [markdown]
# ## 3. Similarity-based reco with filter on geo and topic

# %% [markdown]
# __A. Most similar article after filtering on same `geo`and `topic`__
#
# still using the basic tfidf fitted on  726 articles

# %%
# note : not optimized, greedy filtering just for the sake of the demo
def filter_topic(sample_article, archives_articles):
    my_geo_code = sample_article.geo_code.iloc[0]
    my_topic_code = sample_article.topic_code.iloc[0]
    and_df = archives_articles[(archives_articles["geo_code"]==my_geo_code)&(archives_articles["topic_code"]==my_topic_code)].reset_index()
    if len(and_df)>0:
        ans = and_df
        print("# candidates:", len (ans), "(AND)")

    else :
        ans = archives_articles[(archives_articles["geo_code"]==my_geo_code)|(archives_articles["topic_code"]==my_topic_code)].reset_index()
        print("# candidates:", len (ans), "(OR)")
    return ans

# %%
for i in range(len(sample_df)):
    sample_article = sample_df[sample_df.index==i] # df
    print("\n\n **", sample_df.title[i])
    print(sample_article.geo_code.iloc[0])
    filtered_df = filter_topic(sample_article, labeled_df) # df with new index col
    reco = most_similar(sample_article, filtered_df, transformer=tfidf_vectorizer_base)
    print(reco)    
    print("\nMost similar article:", filtered_df[filtered_df.index==reco[0]].title.iloc[0])
    print(filtered_df.text[reco[0]][:300], '...')
# Out:
#  ** « L’Ickabog », de J. K. Rowling : le triste royaume des Marcheurs
# 2
# # candidates: 8 (AND)
# [0.18470781]
# [0]
#
# Most similar article: L'EUROPE SOUS INFLUENCE
# De la Russie à l'Espagne, la cité royale, modèle politique de l'absolutisme, inspire les princes. Les architectes du roi exportent alors sa gloire. A la fin du xixe siècle, ce sont les imitations kitsch qui fleurissent.
# Versailles n'est pas encore achevé. Mais la cause est déjà entendue. Le xviiie s ...
#
#
#  ** Covid-19 en France : Jean Castex expose la stratégie du gouvernement sur les vaccins
# 3
# # candidates: 73 (AND)
# [0.35991131]
# [1]
#
# Most similar article: Un témoignage exclusif : ainsi finit Phnom Penh
# Récit de l'entrée des Khmers rouges dans Phnom Penh, le 17 avril 1975
# « La fête était finie. Tout craquait, tout s'effondrait. Il n'y avait plus de réjouissances, plus de lieux de plaisir. Les filles de joie avaient disparu, les bars étaient fermés. La nourriture avait atteint des prix astronomiques ...
#
#
#  ** Claude Guéant mis en examen pour « association de malfaiteurs » dans l’affaire du financement libyen de la campagne de 2007
# 3
# # candidates: 34 (AND)
# [0.28973581]
# [31]
#
# Most similar article: RPR : cherchez la femme
# Prises dans les filets de la justice, Xavière Tiberi et Louise-Yvonne Casetta sont des menaces pour le pouvoir. Si elles parlent
# Deux femmes seront-elles fatales au RPR? Par un curieux hasard judiciaire, Xavière Tiberi, épouse du maire de Paris, et Louise-Yvonne Casetta, ancienne trésorière adjointe ...
#
#
#  ** Pédocriminalité : quinze ans de réclusion requis contre l’ex-chirurgien Joël Le Scouarnec
# 3
# # candidates: 34 (AND)
# [0.26059476]
# [33]
#
# Most similar article: Les cabinets d avocats d affaires passes au crible
# La société française est entrée dans l'ère des contentieux : sans pour autant tomber dans la dérive des Etats-Unis, où personne ne peut plus faire un pas sans en appeler à son lawyer, cette fin de siècle sera en France celle du droit et donc des avocats. La loi du 31 décembre 1990, instituant la nou ...
#
#
#  ** Le prix littéraire Interallié décerné à Irène Frain pour « Un crime sans importance »
# 3
# # candidates: 47 (AND)
# [0.14671329]
# [11]
#
# Most similar article: Notre père d'orgueil
# Guerre et paix au pays nantais. Quand l'auteur des «Champs d'honneur» retrouve sa famille et ses jeunes années.
# Jamais, de mémoire de lecteur, on n'avait vu tomber tant d'eau dans un roman. La pluie s'engouffrait dans l'estuaire de la Loire, inondait le pays nantais, marbrait les visages des vivants ...
#
#
#  ** Les championnats de foot reprennent au Maroc et en Tunisie sur fond de crise sanitaire
# 0
# # candidates: 56 (OR)
# [0.16752437]
# [4]
#
# Most similar article: L'aide, malgré tout...
# «Padre nostro, chi sei nei ceili...» Les mains jointes les fidèles massés dans la cathédrale latine d'Asmara, capitale de l'Erythrée, au nord de l'Ethiopie, récitent le Notre Père avec une poignante ferveur. Seuls les petits enfants, agenouillés sous le regard affectueux et parfois grondeur des viei ...
#
#
#  ** Le scandale des employées de maison
# 5
# # candidates: 7 (AND)
# [0.20911167]
# [6]
#
# Most similar article: Les rêves fragiles des jeunes Syriens
# Au cinéma Cham, dans le centre de Damas, les adolescents qui ont les moyens de se payer une place se précipitent depuis quelques mois: on peut y voir de vrais films. Traduction: des films occidentaux et récents. «La semaine dernière, c'était Mort ou vif, qui n'a même pas deux ans! La Syrie change vr ...
#
#
#  ** Mosaïque ethnique dans une zone de tensions
# 0
# # candidates: 31 (AND)
# [0.25504138]
# [3]
#
# Most similar article: Algérie: Les jokers de Chadli
# Presque un an après les émeutes, les réformes se font attendre. En changeant de Premier ministre, 1e président abat ses dernières cartes.
# «Rendez-vous le |e 5 octobre»: onze mois après la sanglante explosion de l'automne dernier, les murs d'Alger se couvrent à nouveau d'inquiétants graffiti. Cet été ...
#
#
#  ** Une population réunie dans la rue contre l’oligarchie et la corruption : Après le « casse du siècle » en Moldavie
# 2
# # candidates: 37 (AND)
# [0.36545649]
# [13]
#
# Most similar article: Les Français au bord de l'Europe
# C'est une étrange aventure qui arrive aux Français: au moment même où ils cherchent à s'isoler, à abriter une vie quiète, perdant tout désir d'expansion, tout esprit de mission salvatrice, les voilà nantis d'une étrange invitation non à table, mais à un chantier.
# Et c'est très vite le désarroi, car  ...
#
#
#  ** Outre-Rhin aussi, médecins et infirmiers dénoncent le « diktat de l’économie »  : Des hôpitaux allemands trop rentables
# 2
# # candidates: 20 (AND)
# [0.39832808]
# [0]
#
# Most similar article: L'envers du paradis en RFA
# Ils passent à l'Ouest pour "l'argent et la liberté". Mais, même s'ils trouvent du travail, "ceux de l'autre côté" ont souvent du mal à s'adapter.
# D'abord, le sentiment de débarquer sur une autre planète, alors qu'on vient du pays d'à côté. Mais, ensuite, à quoi pensent-ils, les nouveaux venus de l'E ...
#
#
#  ** Dossier États-Unis : Changement ou restauration ? Amère victoire démocrate
# 7
# # candidates: 15 (AND)
# [0.35186153]
# [1]
#
# Most similar article: Un grand capitaine
# La semaine prochaine, à Los Angeles, le parti démocrate va désigner l'homme qui doit être prochainement président des Etats-Unis. Ce choix sera probablement: John F. Kennedy, 43 ans. Le journaliste américain Joseph Alsop (1) expose ici, en exclusivité, son opinion sur Kennedy: fait-il le poids"
# La c ...
#
#
#  ** Un rejet exacerbé qui profite aux démagogues. Effets pervers de la lutte anticorruption en Europe centrale
# 2
# # candidates: 37 (AND)
# [0.5265016]
# [13]
#
# Most similar article: Les Français au bord de l'Europe
# C'est une étrange aventure qui arrive aux Français: au moment même où ils cherchent à s'isoler, à abriter une vie quiète, perdant tout désir d'expansion, tout esprit de mission salvatrice, les voilà nantis d'une étrange invitation non à table, mais à un chantier.
# Et c'est très vite le désarroi, car  ...

# %% [markdown]
# __B. More elaborated criterias__
