# %% [markdown]
# # Geoparsing
#
#
# The goal of this notebook is to apply geoparsing to the corpus :
# - build a referential for continents and countries in French
# - retrive LOC entites from a text
# - implement functions to identify continents, countries and cities from a list of LOC entities
# - structure the set of entities as follows : continents/countries/regions/cities /miscellaneous.

# %% [markdown]
# __Imports__

# %%
import geonamescache
import geopy
import pandas as pd

import spacy
try: 
    print("fr_core_news_sm loaded")
    nlp = spacy.load("fr_core_news_sm") # load pre-trained models for French
except:
    print("fr loaded")
    nlp=spacy.load('fr') # fr calls fr_core_news_sm
# Out:
# fr_core_news_sm loaded

# %%
# data
news_df=pd.read_csv("labeled_articles_clean.csv")

news_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  year                              title  \
# 0           0             0  1988               Tintin dans l'espace
# 1           1             1  1988   Le faux suicide de Robert Boulin
# 2           2             2  1988  Des pierres contre les certitudes
# 3           3             3  1988  Otages: soudain, mercredi soir...
# 4           4             4  1988    Les secrets de la planète rouge
#
#                                                 text  \
# 0  Trois semaines à bord de la station soviétique...
# 1  1979 : son corps est découvert en forêt de Ram...
# 2  Rideaux de fer baissés, silhouettes furtives, ...
# 3  " Je lui ai dit: "Ça suffit", et j'ai raccroch...
# 4  S'il existe, dans le système solaire, un seul ...
#
#                                                  url  geo topic  \
# 0  https://www.lexpress.fr/informations/tintin-da...   fr    sc
# 1  https://www.lexpress.fr/actualite/politique/le...   fr    ju
# 2  https://www.lexpress.fr/actualite/monde/proche...   me    po
# 3  https://www.lexpress.fr/informations/otages-so...   me    ju
# 4  https://www.lexpress.fr/actualite/sciences/les...  spa    sc
#
#                                           clean_text  \
# 0  semain bord station soviet jean-loup chrétien ...
# 1  corp découvert forêt rambouillet fauss pist né...
# 2  rideau baiss silhouet furtiv jérusalem arab to...
# 3  suff raccroch trop souvent échaud trop souvent...
# 4  exist system solair seul endroit exobiolog dés...
#
#                  clean_title                  pre_title  \
# 0               tintin espac               tintin espac
# 1  faux suicid robert boulin  faux suicid robert boulin
# 2       pierr contr certitud       pierr contr certitud
# 3  otag soudain mercred soir  otag soudain mercred soir
# 4         secret planet roug         secret planet roug
#
#                                             pre_text  geo_code  topic_code
# 0  semain bord station soviet jean-loup chrétien ...         3           5
# 1  corp découvert forêt rambouillet fauss pist né...         3           2
# 2  rideau baiss silhouet furtiv jérusalem arab to...         5           4
# 3  suff raccroch trop souvent échaud trop souvent...         5           2
# 4  exist system solair seul endroit exobiolog dés...         6           5

# %%
# data from opendata.gouv

country_df = pd.read_csv("./liste_197_etats_2020.csv", encoding = "ISO-8859-1", delimiter=';')
country_df.head(10)
# Out:
#                   NOM           NOM_ALPHA CODE ARTICLE  \
# 0         Afghanistan         Afghanistan  AFG      l'
# 1      Afrique du Sud      Afrique du Sud  ZAF      l'
# 2             Albanie             Albanie  ALB      l'
# 3             Algérie             Algérie  DZA      l'
# 4           Allemagne           Allemagne  DEU      l'
# 5             Andorre             Andorre  AND      l'
# 6              Angola              Angola  AGO      l'
# 7  Antigua-et-Barbuda  Antigua-et-Barbuda  ATG     NaN
# 8     Arabie saoudite     Arabie saoudite  SAU      l'
# 9           Argentine           Argentine  ARG      l'
#
#                                           NOM_LONG            CAPITALE
# 0               République islamique d'Afghanistan              Kaboul
# 1                      République d'Afrique du Sud            Prétoria
# 2                             République d'Albanie              Tirana
# 3  République algérienne démocratique et populaire               Alger
# 4                  République fédérale d'Allemagne              Berlin
# 5                            Principauté d'Andorre  Andorre-la-Vieille
# 6                              République d'Angola              Luanda
# 7                               Antigua-et-Barbuda        Saint John's
# 8                        Royaume d'Arabie saoudite               Riyad
# 9                             République argentine        Buenos Aires

# %% [markdown]
# ## 1. Build tools

# %% [markdown]
# ### 1.1 Build Continent and Country lists in French
#
# using geonamescache

# %%
gc = geonamescache.GeonamesCache()

# %%
# Basic examples for getting started

continents = gc.get_continents()
print(continents.keys())
print(continents['EU'])

countries = gc.get_countries()
print(countries.keys())
print(countries['GB'])
# Out:
# dict_keys(['AF', 'AS', 'EU', 'NA', 'OC', 'SA', 'AN'])
# {'lng': '9.14062', 'geonameId': 6255148, 'timezone': {'gmtOffset': 1, 'timeZoneId': 'Europe/Vaduz', 'dstOffset': 2}, 'bbox': {'east': 41.73303985595703, 'south': 27.6377894797159, 'north': 80.76416015625, 'west': -24.532675386662543, 'accuracyLevel': 0}, 'toponymName': 'Europe', 'asciiName': 'Europe', 'astergdem': 439, 'fcl': 'L', 'population': 741000000, 'wikipediaURL': 'en.wikipedia.org/wiki/Europe', 'adminName5': '', 'srtm3': 443, 'adminName4': '', 'adminName3': '', 'alternateNames': [{'isPreferredName': True, 'name': '유럽', 'lang': 'ko'}, {'name': 'ยุโรป', 'lang': 'th'}, {'name': 'ヨーロッパ', 'lang': 'ja'}, {'name': 'an Eoraip', 'lang': 'ga'}, {'name': 'Avrupa', 'lang': 'tr'}, {'name': 'Châu Âu', 'lang': 'vi'}, {'name': 'Eiropa', 'lang': 'lv'}, {'isColloquial': True, 'name': 'El viejo continente', 'lang': 'es'}, {'name': 'Eropa', 'lang': 'id'}, {'name': 'Eurohpá', 'lang': 'se'}, {'isPreferredName': True, 'name': 'Euroopa', 'lang': 'et'}, {'name': 'Eurooppa', 'lang': 'fi'}, {'isShortName': True, 'isPreferredName': True, 'name': 'Europa', 'lang': 'ca'}, {'name': 'Europa', 'lang': 'da'}, {'isPreferredName': True, 'name': 'Europa', 'lang': 'de'}, {'isShortName': True, 'isPreferredName': True, 'name': 'Europa', 'lang': 'es'}, {'name': 'Europa', 'lang': 'eu'}, {'name': 'Europa', 'lang': 'it'}, {'name': 'Europa', 'lang': 'la'}, {'name': 'Europa', 'lang': 'lt'}, {'name': 'Europa', 'lang': 'nb'}, {'isShortName': True, 'isPreferredName': True, 'name': 'Europa', 'lang': 'nl'}, {'name': 'Europa', 'lang': 'no'}, {'name': 'Europa', 'lang': 'pl'}, {'name': 'Europa', 'lang': 'pt'}, {'isPreferredName': True, 'name': 'Europa', 'lang': 'ro'}, {'name': 'Europa', 'lang': 'sv'}, {'name': 'Európa', 'lang': 'hu'}, {'isPreferredName': True, 'name': 'Európa', 'lang': 'sk'}, {'isPreferredName': True, 'name': 'Europe', 'lang': 'en'}, {'name': 'Europe', 'lang': 'fr'}, {'name': 'Eŭropo', 'lang': 'eo'}, {'name': 'Evropa', 'lang': 'bs'}, {'name': 'Evropa', 'lang': 'cs'}, {'name': 'Evrópa', 'lang': 'is'}, {'name': 'Ewrop', 'lang': 'cy'}, {'name': 'Ewropa', 'lang': 'ku'}, {'name': 'http://id.loc.gov/authorities/subjects/sh85045631', 'lang': 'link'}, {'name': 'https://en.wikipedia.org/wiki/Europe', 'lang': 'link'}, {'name': 'أوروبا', 'lang': 'ar'}, {'name': 'אירופה', 'lang': 'he'}, {'name': 'Ευρώπη', 'lang': 'el'}, {'name': 'Европа', 'lang': 'bg'}, {'isPreferredName': True, 'name': 'Европа', 'lang': 'ru'}, {'name': 'Еўропа', 'lang': 'be'}, {'name': 'Європа', 'lang': 'uk'}, {'name': 'Рашка', 'lang': 'ru'}, {'name': 'यूरोप', 'lang': 'hi'}, {'name': '欧洲', 'lang': 'zh'}], 'cc2': 'AD,AL,AT,AX,BA,BE,BG,BY,CH,CZ,DE,DK,EE,ES,FI,FO,FR,GB,GG,GI,GR,HR,HU,IE,IM,IS,IT,JE,LI,LT,LU,LV,MC,MD,ME,MK,MT,NL,NO,PL,PT,RO,RS,RU,SE,SI,SJ,SK,SM,UA,VA', 'adminName2': '', 'name': 'Europe', 'fclName': 'parks,area, ...', 'fcodeName': 'continent', 'adminName1': '', 'lat': '48.69096', 'fcode': 'CONT', 'continentCode': 'EU'}
# dict_keys(['AD', 'AE', 'AF', 'AG', 'AI', 'AL', 'AM', 'AO', 'AQ', 'AR', 'AS', 'AT', 'AU', 'AW', 'AX', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BL', 'BM', 'BN', 'BO', 'BQ', 'BR', 'BS', 'BT', 'BV', 'BW', 'BY', 'BZ', 'CA', 'CC', 'CD', 'CF', 'CG', 'CH', 'CI', 'CK', 'CL', 'CM', 'CN', 'CO', 'CR', 'CU', 'CV', 'CW', 'CX', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'EH', 'ER', 'ES', 'ET', 'FI', 'FJ', 'FK', 'FM', 'FO', 'FR', 'GA', 'GB', 'GD', 'GE', 'GF', 'GG', 'GH', 'GI', 'GL', 'GM', 'GN', 'GP', 'GQ', 'GR', 'GS', 'GT', 'GU', 'GW', 'GY', 'HK', 'HM', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IM', 'IN', 'IO', 'IQ', 'IR', 'IS', 'IT', 'JE', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KP', 'KR', 'XK', 'KW', 'KY', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MF', 'MG', 'MH', 'MK', 'ML', 'MM', 'MN', 'MO', 'MP', 'MQ', 'MR', 'MS', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NC', 'NE', 'NF', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NU', 'NZ', 'OM', 'PA', 'PE', 'PF', 'PG', 'PH', 'PK', 'PL', 'PM', 'PN', 'PR', 'PS', 'PT', 'PW', 'PY', 'QA', 'RE', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SD', 'SS', 'SE', 'SG', 'SH', 'SI', 'SJ', 'SK', 'SL', 'SM', 'SN', 'SO', 'SR', 'ST', 'SV', 'SX', 'SY', 'SZ', 'TC', 'TD', 'TF', 'TG', 'TH', 'TJ', 'TK', 'TL', 'TM', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'UM', 'US', 'UY', 'UZ', 'VA', 'VC', 'VE', 'VG', 'VI', 'VN', 'VU', 'WF', 'WS', 'YE', 'YT', 'ZA', 'ZM', 'ZW', 'CS', 'AN'])
# {'geonameid': 2635167, 'name': 'United Kingdom', 'iso': 'GB', 'iso3': 'GBR', 'isonumeric': 826, 'fips': 'UK', 'continentcode': 'EU', 'capital': 'London', 'areakm2': 244820, 'population': 62348447, 'tld': '.uk', 'currencycode': 'GBP', 'currencyname': 'Pound', 'phone': '44', 'postalcoderegex': '^([Gg][Ii][Rr] 0[Aa]{2})|((([A-Za-z][0-9]{1,2})|(([A-Za-z][A-Ha-hJ-Yj-y][0-9]{1,2})|(([A-Za-z][0-9][A-Za-z])|([A-Za-z][A-Ha-hJ-Yj-y][0-9]?[A-Za-z])))) [0-9][A-Za-z]{2})$', 'languages': 'en-GB,cy-GB,gd', 'neighbours': 'IE'}

# %%
# Build dictionnary
# keys = continent names in French
# values = dictionnaries with keys 'continantCode', 'country_codes', 'country_code_iso3', 'country_names'

my_continents_fr = dict() # continents.keys()
my_continent_codes = dict() # basic continent_code : french name

for continent_code in continents.keys():
    for dico in continents[continent_code]['alternateNames']:
        # get the french name ?
        if dico['lang']=='fr':
            name_fr = dico['name']
            cont_dico = {'continentCode':continent_code}
            my_continents_fr[name_fr]=cont_dico
            my_continent_codes[continent_code]=name_fr
            if name_fr!='Antarctique':
                my_continents_fr[name_fr]['country_codes']=continents[continent_code]['cc2'].split(',')
            else:
                my_continents_fr[name_fr]['country_codes']=[]
                            
for key in my_continents_fr.keys():
    my_continents_fr[key]['country_code_iso3']=[]
    my_continents_fr[key]['country_names']=[]
    set_noms_fr = set()
    for country_code in my_continents_fr[key]['country_codes']:
        iso3 = countries[country_code]['iso3']
        my_continents_fr[key]['country_code_iso3'].append(iso3)
        
        try:            
            set_noms_fr.add(country_df[country_df['CODE']==iso3]['NOM'].tolist()[0])
            set_noms_fr.add(country_df[country_df['CODE']==iso3]['NOM_ALPHA'].tolist()[0])
            set_noms_fr.add(country_df[country_df['CODE']==iso3]['NOM_LONG'].tolist()[0])            
        except:
            print(countries[country_code])
        set_noms_fr.add(countries[country_code]['name'])
            
    my_continents_fr[key]['country_names']=list(set_noms_fr)

my_continents_fr
# Out:
# {'geonameid': 935317, 'name': 'Reunion', 'iso': 'RE', 'iso3': 'REU', 'isonumeric': 638, 'fips': 'RE', 'continentcode': 'AF', 'capital': 'Saint-Denis', 'areakm2': 2517, 'population': 776948, 'tld': '.re', 'currencycode': 'EUR', 'currencyname': 'Euro', 'phone': '262', 'postalcoderegex': '^((97|98)(4|7|8)\\d{2})$', 'languages': 'fr-RE', 'neighbours': ''}
# {'geonameid': 3370751, 'name': 'Saint Helena', 'iso': 'SH', 'iso3': 'SHN', 'isonumeric': 654, 'fips': 'SH', 'continentcode': 'AF', 'capital': 'Jamestown', 'areakm2': 410, 'population': 7460, 'tld': '.sh', 'currencycode': 'SHP', 'currencyname': 'Pound', 'phone': '290', 'postalcoderegex': '^(STHL1ZZ)$', 'languages': 'en-SH', 'neighbours': ''}
# {'geonameid': 7909807, 'name': 'South Sudan', 'iso': 'SS', 'iso3': 'SSD', 'isonumeric': 728, 'fips': 'OD', 'continentcode': 'AF', 'capital': 'Juba', 'areakm2': 644329, 'population': 8260490, 'tld': '', 'currencycode': 'SSP', 'currencyname': 'Pound', 'phone': '211', 'postalcoderegex': '', 'languages': 'en', 'neighbours': 'CD,CF,ET,KE,SD,UG'}
# {'geonameid': 1024031, 'name': 'Mayotte', 'iso': 'YT', 'iso3': 'MYT', 'isonumeric': 175, 'fips': 'MF', 'continentcode': 'AF', 'capital': 'Mamoudzou', 'areakm2': 374, 'population': 159042, 'tld': '.yt', 'currencycode': 'EUR', 'currencyname': 'Euro', 'phone': '262', 'postalcoderegex': '^(\\d{5})$', 'languages': 'fr-YT', 'neighbours': ''}
# {'geonameid': 1819730, 'name': 'Hong Kong', 'iso': 'HK', 'iso3': 'HKG', 'isonumeric': 344, 'fips': 'HK', 'continentcode': 'AS', 'capital': 'Hong Kong', 'areakm2': 1092, 'population': 6898686, 'tld': '.hk', 'currencycode': 'HKD', 'currencyname': 'Dollar', 'phone': '852', 'postalcoderegex': '', 'languages': 'zh-HK,yue,zh,en', 'neighbours': ''}
# {'geonameid': 1821275, 'name': 'Macao', 'iso': 'MO', 'iso3': 'MAC', 'isonumeric': 446, 'fips': 'MC', 'continentcode': 'AS', 'capital': 'Macao', 'areakm2': 254, 'population': 449198, 'tld': '.mo', 'currencycode': 'MOP', 'currencyname': 'Pataca', 'phone': '853', 'postalcoderegex': '', 'languages': 'zh,zh-MO,pt', 'neighbours': ''}
# {'geonameid': 6254930, 'name': 'Palestinian Territory', 'iso': 'PS', 'iso3': 'PSE', 'isonumeric': 275, 'fips': 'WE', 'continentcode': 'AS', 'capital': 'East Jerusalem', 'areakm2': 5970, 'population': 3800000, 'tld': '.ps', 'currencycode': 'ILS', 'currencyname': 'Shekel', 'phone': '970', 'postalcoderegex': '', 'languages': 'ar-PS', 'neighbours': 'JO,IL,EG'}
# {'geonameid': 1668284, 'name': 'Taiwan', 'iso': 'TW', 'iso3': 'TWN', 'isonumeric': 158, 'fips': 'TW', 'continentcode': 'AS', 'capital': 'Taipei', 'areakm2': 35980, 'population': 22894384, 'tld': '.tw', 'currencycode': 'TWD', 'currencyname': 'Dollar', 'phone': '886', 'postalcoderegex': '^(\\d{5})$', 'languages': 'zh-TW,zh,nan,hak', 'neighbours': ''}
# {'geonameid': 661882, 'name': 'Aland Islands', 'iso': 'AX', 'iso3': 'ALA', 'isonumeric': 248, 'fips': '', 'continentcode': 'EU', 'capital': 'Mariehamn', 'areakm2': 1580, 'population': 26711, 'tld': '.ax', 'currencycode': 'EUR', 'currencyname': 'Euro', 'phone': '+358-18', 'postalcoderegex': '^(?:FI)*(\\d{5})$', 'languages': 'sv-AX', 'neighbours': ''}
# {'geonameid': 2622320, 'name': 'Faroe Islands', 'iso': 'FO', 'iso3': 'FRO', 'isonumeric': 234, 'fips': 'FO', 'continentcode': 'EU', 'capital': 'Torshavn', 'areakm2': 1399, 'population': 48228, 'tld': '.fo', 'currencycode': 'DKK', 'currencyname': 'Krone', 'phone': '298', 'postalcoderegex': '^(?:FO)*(\\d{3})$', 'languages': 'fo,da-FO', 'neighbours': ''}
# {'geonameid': 3042362, 'name': 'Guernsey', 'iso': 'GG', 'iso3': 'GGY', 'isonumeric': 831, 'fips': 'GK', 'continentcode': 'EU', 'capital': 'St Peter Port', 'areakm2': 78, 'population': 65228, 'tld': '.gg', 'currencycode': 'GBP', 'currencyname': 'Pound', 'phone': '+44-1481', 'postalcoderegex': '^((?:(?:[A-PR-UWYZ][A-HK-Y]\\d[ABEHMNPRV-Y0-9]|[A-PR-UWYZ]\\d[A-HJKPS-UW0-9])\\s\\d[ABD-HJLNP-UW-Z]{2})|GIR\\s?0AA)$', 'languages': 'en,nrf', 'neighbours': ''}
# {'geonameid': 2411586, 'name': 'Gibraltar', 'iso': 'GI', 'iso3': 'GIB', 'isonumeric': 292, 'fips': 'GI', 'continentcode': 'EU', 'capital': 'Gibraltar', 'areakm2': 6, 'population': 27884, 'tld': '.gi', 'currencycode': 'GIP', 'currencyname': 'Pound', 'phone': '350', 'postalcoderegex': '', 'languages': 'en-GI,es,it,pt', 'neighbours': 'ES'}
# {'geonameid': 3042225, 'name': 'Isle of Man', 'iso': 'IM', 'iso3': 'IMN', 'isonumeric': 833, 'fips': 'IM', 'continentcode': 'EU', 'capital': 'Douglas', 'areakm2': 572, 'population': 75049, 'tld': '.im', 'currencycode': 'GBP', 'currencyname': 'Pound', 'phone': '+44-1624', 'postalcoderegex': '^((?:(?:[A-PR-UWYZ][A-HK-Y]\\d[ABEHMNPRV-Y0-9]|[A-PR-UWYZ]\\d[A-HJKPS-UW0-9])\\s\\d[ABD-HJLNP-UW-Z]{2})|GIR\\s?0AA)$', 'languages': 'en,gv', 'neighbours': ''}
# {'geonameid': 3042142, 'name': 'Jersey', 'iso': 'JE', 'iso3': 'JEY', 'isonumeric': 832, 'fips': 'JE', 'continentcode': 'EU', 'capital': 'Saint Helier', 'areakm2': 116, 'population': 90812, 'tld': '.je', 'currencycode': 'GBP', 'currencyname': 'Pound', 'phone': '+44-1534', 'postalcoderegex': '^((?:(?:[A-PR-UWYZ][A-HK-Y]\\d[ABEHMNPRV-Y0-9]|[A-PR-UWYZ]\\d[A-HJKPS-UW0-9])\\s\\d[ABD-HJLNP-UW-Z]{2})|GIR\\s?0AA)$', 'languages': 'en,fr,nrf', 'neighbours': ''}
# {'geonameid': 607072, 'name': 'Svalbard and Jan Mayen', 'iso': 'SJ', 'iso3': 'SJM', 'isonumeric': 744, 'fips': 'SV', 'continentcode': 'EU', 'capital': 'Longyearbyen', 'areakm2': 62049, 'population': 2550, 'tld': '.sj', 'currencycode': 'NOK', 'currencyname': 'Krone', 'phone': '47', 'postalcoderegex': '^(\\d{4})$', 'languages': 'no,ru', 'neighbours': ''}
# {'geonameid': 3573511, 'name': 'Anguilla', 'iso': 'AI', 'iso3': 'AIA', 'isonumeric': 660, 'fips': 'AV', 'continentcode': 'NA', 'capital': 'The Valley', 'areakm2': 102, 'population': 13254, 'tld': '.ai', 'currencycode': 'XCD', 'currencyname': 'Dollar', 'phone': '+1-264', 'postalcoderegex': '', 'languages': 'en-AI', 'neighbours': ''}
# {'geonameid': 3577279, 'name': 'Aruba', 'iso': 'AW', 'iso3': 'ABW', 'isonumeric': 533, 'fips': 'AA', 'continentcode': 'NA', 'capital': 'Oranjestad', 'areakm2': 193, 'population': 71566, 'tld': '.aw', 'currencycode': 'AWG', 'currencyname': 'Guilder', 'phone': '297', 'postalcoderegex': '', 'languages': 'nl-AW,pap,es,en', 'neighbours': ''}
# {'geonameid': 3578476, 'name': 'Saint Barthelemy', 'iso': 'BL', 'iso3': 'BLM', 'isonumeric': 652, 'fips': 'TB', 'continentcode': 'NA', 'capital': 'Gustavia', 'areakm2': 21, 'population': 8450, 'tld': '.gp', 'currencycode': 'EUR', 'currencyname': 'Euro', 'phone': '590', 'postalcoderegex': '^(\\d{5})$', 'languages': 'fr', 'neighbours': ''}
# {'geonameid': 3573345, 'name': 'Bermuda', 'iso': 'BM', 'iso3': 'BMU', 'isonumeric': 60, 'fips': 'BD', 'continentcode': 'NA', 'capital': 'Hamilton', 'areakm2': 53, 'population': 65365, 'tld': '.bm', 'currencycode': 'BMD', 'currencyname': 'Dollar', 'phone': '+1-441', 'postalcoderegex': '^([A-Z]{2}\\d{2})$', 'languages': 'en-BM,pt', 'neighbours': ''}
# {'geonameid': 7626844, 'name': 'Bonaire, Saint Eustatius and Saba ', 'iso': 'BQ', 'iso3': 'BES', 'isonumeric': 535, 'fips': '', 'continentcode': 'NA', 'capital': '', 'areakm2': 328, 'population': 18012, 'tld': '.bq', 'currencycode': 'USD', 'currencyname': 'Dollar', 'phone': '599', 'postalcoderegex': '', 'languages': 'nl,pap,en', 'neighbours': ''}
# {'geonameid': 7626836, 'name': 'Curacao', 'iso': 'CW', 'iso3': 'CUW', 'isonumeric': 531, 'fips': 'UC', 'continentcode': 'NA', 'capital': ' Willemstad', 'areakm2': 444, 'population': 141766, 'tld': '.cw', 'currencycode': 'ANG', 'currencyname': 'Guilder', 'phone': '599', 'postalcoderegex': '', 'languages': 'nl,pap', 'neighbours': ''}
# {'geonameid': 3425505, 'name': 'Greenland', 'iso': 'GL', 'iso3': 'GRL', 'isonumeric': 304, 'fips': 'GL', 'continentcode': 'NA', 'capital': 'Nuuk', 'areakm2': 2166086, 'population': 56375, 'tld': '.gl', 'currencycode': 'DKK', 'currencyname': 'Krone', 'phone': '299', 'postalcoderegex': '^(\\d{4})$', 'languages': 'kl,da-GL,en', 'neighbours': ''}
# {'geonameid': 3579143, 'name': 'Guadeloupe', 'iso': 'GP', 'iso3': 'GLP', 'isonumeric': 312, 'fips': 'GP', 'continentcode': 'NA', 'capital': 'Basse-Terre', 'areakm2': 1780, 'population': 443000, 'tld': '.gp', 'currencycode': 'EUR', 'currencyname': 'Euro', 'phone': '590', 'postalcoderegex': '^((97|98)\\d{3})$', 'languages': 'fr-GP', 'neighbours': ''}
# {'geonameid': 3580718, 'name': 'Cayman Islands', 'iso': 'KY', 'iso3': 'CYM', 'isonumeric': 136, 'fips': 'CJ', 'continentcode': 'NA', 'capital': 'George Town', 'areakm2': 262, 'population': 44270, 'tld': '.ky', 'currencycode': 'KYD', 'currencyname': 'Dollar', 'phone': '+1-345', 'postalcoderegex': '', 'languages': 'en-KY', 'neighbours': ''}
# {'geonameid': 3578421, 'name': 'Saint Martin', 'iso': 'MF', 'iso3': 'MAF', 'isonumeric': 663, 'fips': 'RN', 'continentcode': 'NA', 'capital': 'Marigot', 'areakm2': 53, 'population': 35925, 'tld': '.gp', 'currencycode': 'EUR', 'currencyname': 'Euro', 'phone': '590', 'postalcoderegex': '^(\\d{5})$', 'languages': 'fr', 'neighbours': 'SX'}
# {'geonameid': 3570311, 'name': 'Martinique', 'iso': 'MQ', 'iso3': 'MTQ', 'isonumeric': 474, 'fips': 'MB', 'continentcode': 'NA', 'capital': 'Fort-de-France', 'areakm2': 1100, 'population': 432900, 'tld': '.mq', 'currencycode': 'EUR', 'currencyname': 'Euro', 'phone': '596', 'postalcoderegex': '^(\\d{5})$', 'languages': 'fr-MQ', 'neighbours': ''}
# {'geonameid': 3578097, 'name': 'Montserrat', 'iso': 'MS', 'iso3': 'MSR', 'isonumeric': 500, 'fips': 'MH', 'continentcode': 'NA', 'capital': 'Plymouth', 'areakm2': 102, 'population': 9341, 'tld': '.ms', 'currencycode': 'XCD', 'currencyname': 'Dollar', 'phone': '+1-664', 'postalcoderegex': '', 'languages': 'en-MS', 'neighbours': ''}
# {'geonameid': 3424932, 'name': 'Saint Pierre and Miquelon', 'iso': 'PM', 'iso3': 'SPM', 'isonumeric': 666, 'fips': 'SB', 'continentcode': 'NA', 'capital': 'Saint-Pierre', 'areakm2': 242, 'population': 7012, 'tld': '.pm', 'currencycode': 'EUR', 'currencyname': 'Euro', 'phone': '508', 'postalcoderegex': '^(97500)$', 'languages': 'fr-PM', 'neighbours': ''}
# {'geonameid': 4566966, 'name': 'Puerto Rico', 'iso': 'PR', 'iso3': 'PRI', 'isonumeric': 630, 'fips': 'RQ', 'continentcode': 'NA', 'capital': 'San Juan', 'areakm2': 9104, 'population': 3916632, 'tld': '.pr', 'currencycode': 'USD', 'currencyname': 'Dollar', 'phone': '+1-787 and 1-939', 'postalcoderegex': '^00[679]\\d{2}(?:-\\d{4})?$', 'languages': 'en-PR,es-PR', 'neighbours': ''}
# {'geonameid': 7609695, 'name': 'Sint Maarten', 'iso': 'SX', 'iso3': 'SXM', 'isonumeric': 534, 'fips': 'NN', 'continentcode': 'NA', 'capital': 'Philipsburg', 'areakm2': 21, 'population': 37429, 'tld': '.sx', 'currencycode': 'ANG', 'currencyname': 'Guilder', 'phone': '599', 'postalcoderegex': '', 'languages': 'nl,en', 'neighbours': 'MF'}
# {'geonameid': 3576916, 'name': 'Turks and Caicos Islands', 'iso': 'TC', 'iso3': 'TCA', 'isonumeric': 796, 'fips': 'TK', 'continentcode': 'NA', 'capital': 'Cockburn Town', 'areakm2': 430, 'population': 20556, 'tld': '.tc', 'currencycode': 'USD', 'currencyname': 'Dollar', 'phone': '+1-649', 'postalcoderegex': '^(TKCA 1ZZ)$', 'languages': 'en-TC', 'neighbours': ''}
# {'geonameid': 3577718, 'name': 'British Virgin Islands', 'iso': 'VG', 'iso3': 'VGB', 'isonumeric': 92, 'fips': 'VI', 'continentcode': 'NA', 'capital': 'Road Town', 'areakm2': 153, 'population': 21730, 'tld': '.vg', 'currencycode': 'USD', 'currencyname': 'Dollar', 'phone': '+1-284', 'postalcoderegex': '', 'languages': 'en-VG', 'neighbours': ''}
# {'geonameid': 4796775, 'name': 'U.S. Virgin Islands', 'iso': 'VI', 'iso3': 'VIR', 'isonumeric': 850, 'fips': 'VQ', 'continentcode': 'NA', 'capital': 'Charlotte Amalie', 'areakm2': 352, 'population': 108708, 'tld': '.vi', 'currencycode': 'USD', 'currencyname': 'Dollar', 'phone': '+1-340', 'postalcoderegex': '^008\\d{2}(?:-\\d{4})?$', 'languages': 'en-VI', 'neighbours': ''}
# {'geonameid': 4043988, 'name': 'Guam', 'iso': 'GU', 'iso3': 'GUM', 'isonumeric': 316, 'fips': 'GQ', 'continentcode': 'OC', 'capital': 'Hagatna', 'areakm2': 549, 'population': 159358, 'tld': '.gu', 'currencycode': 'USD', 'currencyname': 'Dollar', 'phone': '+1-671', 'postalcoderegex': '^(969\\d{2})$', 'languages': 'en-GU,ch-GU', 'neighbours': ''}
# {'geonameid': 2139685, 'name': 'New Caledonia', 'iso': 'NC', 'iso3': 'NCL', 'isonumeric': 540, 'fips': 'NC', 'continentcode': 'OC', 'capital': 'Noumea', 'areakm2': 19060, 'population': 216494, 'tld': '.nc', 'currencycode': 'XPF', 'currencyname': 'Franc', 'phone': '687', 'postalcoderegex': '^(\\d{5})$', 'languages': 'fr-NC', 'neighbours': ''}
# {'geonameid': 2155115, 'name': 'Norfolk Island', 'iso': 'NF', 'iso3': 'NFK', 'isonumeric': 574, 'fips': 'NF', 'continentcode': 'OC', 'capital': 'Kingston', 'areakm2': 34, 'population': 1828, 'tld': '.nf', 'currencycode': 'AUD', 'currencyname': 'Dollar', 'phone': '672', 'postalcoderegex': '^(\\d{4})$', 'languages': 'en-NF', 'neighbours': ''}
# {'geonameid': 4030699, 'name': 'Pitcairn', 'iso': 'PN', 'iso3': 'PCN', 'isonumeric': 612, 'fips': 'PC', 'continentcode': 'OC', 'capital': 'Adamstown', 'areakm2': 47, 'population': 46, 'tld': '.pn', 'currencycode': 'NZD', 'currencyname': 'Dollar', 'phone': '870', 'postalcoderegex': '', 'languages': 'en-PN', 'neighbours': ''}
# {'geonameid': 4031074, 'name': 'Tokelau', 'iso': 'TK', 'iso3': 'TKL', 'isonumeric': 772, 'fips': 'TL', 'continentcode': 'OC', 'capital': '', 'areakm2': 10, 'population': 1466, 'tld': '.tk', 'currencycode': 'NZD', 'currencyname': 'Dollar', 'phone': '690', 'postalcoderegex': '', 'languages': 'tkl,en-TK', 'neighbours': ''}
# {'geonameid': 4034749, 'name': 'Wallis and Futuna', 'iso': 'WF', 'iso3': 'WLF', 'isonumeric': 876, 'fips': 'WF', 'continentcode': 'OC', 'capital': 'Mata Utu', 'areakm2': 274, 'population': 16025, 'tld': '.wf', 'currencycode': 'XPF', 'currencyname': 'Franc', 'phone': '681', 'postalcoderegex': '^(986\\d{2})$', 'languages': 'wls,fud,fr-WF', 'neighbours': ''}
# {'geonameid': 3381670, 'name': 'French Guiana', 'iso': 'GF', 'iso3': 'GUF', 'isonumeric': 254, 'fips': 'FG', 'continentcode': 'SA', 'capital': 'Cayenne', 'areakm2': 91000, 'population': 195506, 'tld': '.gf', 'currencycode': 'EUR', 'currencyname': 'Euro', 'phone': '594', 'postalcoderegex': '^((97|98)3\\d{2})$', 'languages': 'fr-GF', 'neighbours': 'SR,BR'}
# {'geonameid': 3474414, 'name': 'Falkland Islands', 'iso': 'FK', 'iso3': 'FLK', 'isonumeric': 238, 'fips': 'FK', 'continentcode': 'SA', 'capital': 'Stanley', 'areakm2': 12173, 'population': 2638, 'tld': '.fk', 'currencycode': 'FKP', 'currencyname': 'Pound', 'phone': '500', 'postalcoderegex': '', 'languages': 'en-FK', 'neighbours': ''}
# {'AF': 'Afrique', 'AS': 'Asie', 'EU': 'Europe', 'NA': 'Amérique du Nord', 'OC': 'Océanie', 'SA': 'Amérique du Sud', 'AN': 'Antarctique'}
# {'Afrique': {'continentCode': 'AF',
#   'country_codes': ['AO',
#    'BF',
#    'BI',
#    'BJ',
#    'BW',
#    'CD',
#    'CF',
#    'CG',
#    'CI',
#    'CM',
#    'CV',
#    'DJ',
#    'DZ',
#    'EG',
#    'ER',
#    'ET',
#    'GA',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GW',
#    'KE',
#    'KM',
#    'LR',
#    'LS',
#    'LY',
#    'MA',
#    'MG',
#    'ML',
#    'MR',
#    'MU',
#    'MW',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'RE',
#    'RW',
#    'SC',
#    'SD',
#    'SH',
#    'SL',
#    'SN',
#    'SO',
#    'SS',
#    'ST',
#    'SZ',
#    'TD',
#    'TG',
#    'TN',
#    'TZ',
#    'UG',
#    'YT',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'country_code_iso3': ['AGO',
#    'BFA',
#    'BDI',
#    'BEN',
#    'BWA',
#    'COD',
#    'CAF',
#    'COG',
#    'CIV',
#    'CMR',
#    'CPV',
#    'DJI',
#    'DZA',
#    'EGY',
#    'ERI',
#    'ETH',
#    'GAB',
#    'GHA',
#    'GMB',
#    'GIN',
#    'GNQ',
#    'GNB',
#    'KEN',
#    'COM',
#    'LBR',
#    'LSO',
#    'LBY',
#    'MAR',
#    'MDG',
#    'MLI',
#    'MRT',
#    'MUS',
#    'MWI',
#    'MOZ',
#    'NAM',
#    'NER',
#    'NGA',
#    'REU',
#    'RWA',
#    'SYC',
#    'SDN',
#    'SHN',
#    'SLE',
#    'SEN',
#    'SOM',
#    'SSD',
#    'STP',
#    'SWZ',
#    'TCD',
#    'TGO',
#    'TUN',
#    'TZA',
#    'UGA',
#    'MYT',
#    'ZAF',
#    'ZMB',
#    'ZWE'],
#   'country_names': ['Benin',
#    'Algérie',
#    'République togolaise',
#    'Burkina',
#    'République gabonaise',
#    'Kenya',
#    'Zambia',
#    'Angola',
#    'Guinée-Bissao',
#    'Lésotho',
#    'Mauritania',
#    'République de Sierra Leone',
#    'Rwanda',
#    'République du Bénin',
#    'Equatorial Guinea',
#    'Eswatini',
#    'Royaume du Lesotho',
#    "République arabe d'Égypte",
#    'République du Mozambique',
#    'République du Soudan',
#    'République de Zambie',
#    'République de Maurice',
#    'Érythrée',
#    'Zambie',
#    'Sudan',
#    'Sao Tome and Principe',
#    'République fédérale de Somalie',
#    'Egypt',
#    'Gambia',
#    'Djibouti',
#    'Guinée équatoriale',
#    'Maurice',
#    'Zimbabwe',
#    'Éthiopie',
#    'État de Libye',
#    'République des Seychelles',
#    'Mali',
#    'Sénégal',
#    'République du Botswana',
#    'République du Zimbabwé',
#    'South Africa',
#    'Tunisie',
#    'Burkina Faso',
#    'Reunion',
#    'Kénya',
#    'Cameroon',
#    'Mauritanie',
#    'République du Kénya',
#    'République du Rwanda',
#    'Maroc',
#    'République islamique de Mauritanie',
#    'République du Ghana',
#    'République du Libéria',
#    'Gambie',
#    'Comoros',
#    'Lesotho',
#    'Union des Comores',
#    "République de Côte d'Ivoire",
#    'République du Burundi',
#    'Eritrea',
#    'Liberia',
#    'Mayotte',
#    'République de Namibie',
#    'Ivory Coast',
#    'République tunisienne',
#    'Botswana',
#    'Malawi',
#    'République démocratique de Sao Tomé-et-Principe',
#    'Seychelles',
#    'Soudan',
#    'République du Malawi',
#    'République fédérale du Nigéria',
#    'Ethiopia',
#    'Ghana',
#    'République centrafricaine',
#    "République d'Angola",
#    'République du Tchad',
#    'République unie de Tanzanie',
#    'République de Guinée équatoriale',
#    'Mozambique',
#    'Cap-Vert',
#    'République de Gambie',
#    'Togo',
#    'Madagascar',
#    "État d'Érythrée",
#    'Sao Tomé-et-Principe',
#    'Libéria',
#    'Guinée',
#    'République du Cap-Vert',
#    'Royaume du Maroc',
#    "République d'Ouganda",
#    'Cameroun',
#    'République du Sénégal',
#    'Guinea-Bissau',
#    'Tchad',
#    'République démocratique du Congo',
#    'Guinea',
#    'Ouganda',
#    "Royaume d'Eswatini",
#    'Comores',
#    'Nigeria',
#    'République de Guinée',
#    "République d'Afrique du Sud",
#    'Senegal',
#    'Nigéria',
#    'Libya',
#    'Morocco',
#    'Congo (République démocratique du)',
#    'Tunisia',
#    "République démocratique fédérale d'Éthiopie",
#    'Tanzanie',
#    'Niger',
#    'République du Congo',
#    'République algérienne démocratique et populaire',
#    'Zimbabwé',
#    'Burundi',
#    'République de Djibouti',
#    'Tanzania',
#    'Sierra Leone',
#    'Centrafrique',
#    'République du Niger',
#    'Bénin',
#    'Gabon',
#    'Central African Republic',
#    'Republic of the Congo',
#    'Égypte',
#    'Libye',
#    'Algeria',
#    'South Sudan',
#    'Congo',
#    'Namibie',
#    "Côte d'Ivoire",
#    'Saint Helena',
#    'Namibia',
#    'Cabo Verde',
#    'Chad',
#    'Somalia',
#    'République de Madagascar',
#    'République de Guinée-Bissao',
#    'Afrique du Sud',
#    'Mauritius',
#    'République du Mali',
#    'Uganda',
#    'Somalie',
#    'République du Cameroun',
#    'Democratic Republic of the Congo']},
#  'Asie': {'continentCode': 'AS',
#   'country_codes': ['AE',
#    'AF',
#    'AM',
#    'AZ',
#    'BD',
#    'BH',
#    'BN',
#    'BT',
#    'CN',
#    'CY',
#    'GE',
#    'HK',
#    'ID',
#    'IL',
#    'IN',
#    'IQ',
#    'IR',
#    'JO',
#    'JP',
#    'KG',
#    'KH',
#    'KP',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LK',
#    'MM',
#    'MN',
#    'MO',
#    'MV',
#    'MY',
#    'NP',
#    'OM',
#    'PH',
#    'PK',
#    'PS',
#    'QA',
#    'SA',
#    'SG',
#    'SY',
#    'TH',
#    'TJ',
#    'TL',
#    'TM',
#    'TR',
#    'TW',
#    'UZ',
#    'VN',
#    'YE'],
#   'country_code_iso3': ['ARE',
#    'AFG',
#    'ARM',
#    'AZE',
#    'BGD',
#    'BHR',
#    'BRN',
#    'BTN',
#    'CHN',
#    'CYP',
#    'GEO',
#    'HKG',
#    'IDN',
#    'ISR',
#    'IND',
#    'IRQ',
#    'IRN',
#    'JOR',
#    'JPN',
#    'KGZ',
#    'KHM',
#    'PRK',
#    'KOR',
#    'KWT',
#    'KAZ',
#    'LAO',
#    'LBN',
#    'LKA',
#    'MMR',
#    'MNG',
#    'MAC',
#    'MDV',
#    'MYS',
#    'NPL',
#    'OMN',
#    'PHL',
#    'PAK',
#    'PSE',
#    'QAT',
#    'SAU',
#    'SGP',
#    'SYR',
#    'THA',
#    'TJK',
#    'TLS',
#    'TKM',
#    'TUR',
#    'TWN',
#    'UZB',
#    'VNM',
#    'YEM'],
#   'country_names': ['Pakistan',
#    'South Korea',
#    'Tajikistan',
#    'République populaire de Chine',
#    "République d'Azerbaïdjan",
#    'Afghanistan',
#    'République populaire du Bangladesh',
#    'Georgia',
#    'Hong Kong',
#    'Japan',
#    'Chypre',
#    'République des Maldives',
#    'Jordan',
#    'République arabe syrienne',
#    'République islamique du Pakistan',
#    'Singapore',
#    'État du Koweït',
#    "République d'Arménie",
#    'République démocratique fédérale du Népal',
#    'République du Yémen',
#    'Liban',
#    'Saudi Arabia',
#    'République socialiste du Vietnam',
#    'Bhutan',
#    "État d'Israël",
#    "République islamique d'Iran",
#    'Syria',
#    'Iraq',
#    'République de Corée',
#    'Kirghizstan',
#    'Royaume hachémite de Jordanie',
#    'Sri Lanka',
#    "République d'Ouzbékistan",
#    'République des Philippines',
#    'Royaume de Bahreïn',
#    'Inde',
#    'Turquie',
#    'Émirats arabes unis',
#    'Corée du Sud',
#    'Timor Leste',
#    'Cambodia',
#    'Myanmar',
#    'République de Chypre',
#    'Israel',
#    'Syrie',
#    'Iran',
#    'République du Kazakhstan',
#    'Lebanon',
#    'India',
#    'Laos',
#    'République de Singapour',
#    'Corée du Nord',
#    'Malaysia',
#    'Azerbaïdjan',
#    'China',
#    "République d'Irak",
#    'Royaume de Thaïlande',
#    'Turkmenistan',
#    'Bahreïn',
#    'État du Qatar',
#    'Singapour',
#    'United Arab Emirates',
#    'Malaisie',
#    'Ouzbékistan',
#    'Kyrgyzstan',
#    'Géorgie',
#    'Brunei Darussalam',
#    'Arabie saoudite',
#    'Bahrain',
#    'Irak',
#    'Népal',
#    'Nepal',
#    'République kirghize',
#    'Israël',
#    'Uzbekistan',
#    'Yémen',
#    'Oman',
#    "République de l'Inde",
#    'Turkménistan',
#    'Thailand',
#    "République islamique d'Afghanistan",
#    'Royaume du Bhoutan',
#    'Qatar',
#    'Taiwan',
#    'Thaïlande',
#    'Indonésie',
#    'Arménie',
#    'Cambodge',
#    'Palestinian Territory',
#    'Indonesia',
#    'République libanaise',
#    'République démocratique populaire lao',
#    'Kazakhstan',
#    'Cyprus',
#    'Mongolie',
#    'République de Turquie',
#    'Macao',
#    "République d'Indonésie",
#    'Vietnam',
#    'Japon',
#    'Azerbaijan',
#    "Royaume d'Arabie saoudite",
#    'Timor oriental',
#    'République démocratique du Timor oriental',
#    'Chine',
#    'Tadjikistan',
#    'North Korea',
#    "Sultanat d'Oman",
#    'Yemen',
#    'Royaume du Cambodge',
#    'Turkey',
#    'Koweït',
#    'Bhoutan',
#    'République démocratique socialiste du Sri Lanka',
#    'Philippines',
#    'République populaire démocratique de Corée',
#    'Kuwait',
#    'Jordanie',
#    'Bangladesh',
#    'Armenia',
#    'Brunei',
#    'Maldives',
#    'République du Tadjikistan',
#    "République de l'Union de Birmanie",
#    'Mongolia',
#    'Birmanie']},
#  'Europe': {'continentCode': 'EU',
#   'country_codes': ['AD',
#    'AL',
#    'AT',
#    'AX',
#    'BA',
#    'BE',
#    'BG',
#    'BY',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FO',
#    'FR',
#    'GB',
#    'GG',
#    'GI',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IM',
#    'IS',
#    'IT',
#    'JE',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'NL',
#    'NO',
#    'PL',
#    'PT',
#    'RO',
#    'RS',
#    'RU',
#    'SE',
#    'SI',
#    'SJ',
#    'SK',
#    'SM',
#    'UA',
#    'VA'],
#   'country_code_iso3': ['AND',
#    'ALB',
#    'AUT',
#    'ALA',
#    'BIH',
#    'BEL',
#    'BGR',
#    'BLR',
#    'CHE',
#    'CZE',
#    'DEU',
#    'DNK',
#    'EST',
#    'ESP',
#    'FIN',
#    'FRO',
#    'FRA',
#    'GBR',
#    'GGY',
#    'GIB',
#    'GRC',
#    'HRV',
#    'HUN',
#    'IRL',
#    'IMN',
#    'ISL',
#    'ITA',
#    'JEY',
#    'LIE',
#    'LTU',
#    'LUX',
#    'LVA',
#    'MCO',
#    'MDA',
#    'MNE',
#    'MKD',
#    'MLT',
#    'NLD',
#    'NOR',
#    'POL',
#    'PRT',
#    'ROU',
#    'SRB',
#    'RUS',
#    'SWE',
#    'SVN',
#    'SJM',
#    'SVK',
#    'SMR',
#    'UKR',
#    'VAT'],
#   'country_names': ['Italy',
#    'Jersey',
#    'Macédoine du Nord',
#    'République de Biélorussie',
#    'Svalbard and Jan Mayen',
#    "République fédérale d'Allemagne",
#    'Italie',
#    'Albanie',
#    'Finlande',
#    'Belgium',
#    'Guernsey',
#    'Montenegro',
#    'Austria',
#    'Bulgaria',
#    'Islande',
#    'Lettonie',
#    'République portugaise',
#    'San Marino',
#    'Slovaquie',
#    'Albania',
#    'Finland',
#    'Lituanie',
#    'République de Lituanie',
#    'Danemark',
#    "République d'Estonie",
#    'Faroe Islands',
#    'Grèce',
#    'Aland Islands',
#    'United Kingdom',
#    'Andorra',
#    'Principauté du Liechtenstein',
#    'Grand-Duché de Luxembourg',
#    'Poland',
#    'North Macedonia',
#    "Principauté d'Andorre",
#    'Tchéquie',
#    'Croatie',
#    'Belarus',
#    'Espagne',
#    'Belgique',
#    'Ukraine',
#    "République d'Albanie",
#    'Suisse',
#    'Greece',
#    'Sweden',
#    'France',
#    'Vatican',
#    'Portugal',
#    'Latvia',
#    'République de Moldavie',
#    'République de Macédoine du Nord',
#    'République de Slovénie',
#    'Isle of Man',
#    'Liechtenstein',
#    'Bosnia and Herzegovina',
#    'Ireland',
#    "République d'Islande",
#    "Royaume d'Espagne",
#    'République de Serbie',
#    'République de Pologne',
#    'Croatia',
#    'Russia',
#    'Andorre',
#    'Biélorussie',
#    'Allemagne',
#    'République française',
#    'Bosnie-Herzégovine',
#    'République de Saint-Marin',
#    'Hungary',
#    'Slovakia',
#    'Principauté de Monaco',
#    'Gibraltar',
#    'Irlande',
#    'Pays-Bas',
#    'République de Bulgarie',
#    'République slovaque',
#    'Romania',
#    'Suède',
#    'Denmark',
#    'Czechia',
#    'Serbie',
#    'Moldova',
#    'Saint-Marin',
#    'Royaume-Uni',
#    'République italienne',
#    'Pologne',
#    'Royaume de Suède',
#    'Royaume de Norvège',
#    'Malte',
#    'Lithuania',
#    'Netherlands',
#    'Norvège',
#    'Switzerland',
#    'République hellénique',
#    'République de Lettonie',
#    'Germany',
#    'Slovenia',
#    'Monténégro',
#    'Bulgarie',
#    'Malta',
#    'Autriche',
#    'Vatican (Saint-Siège)',
#    'Estonia',
#    'Iceland',
#    'Roumanie',
#    'Monaco',
#    'République de Finlande',
#    'République tchèque',
#    'Estonie',
#    'Royaume du Danemark',
#    'Serbia',
#    'Fédération de Russie',
#    "Royaume-Uni de Grande-Bretagne et d'Irlande du Nord",
#    'République de Croatie',
#    'République de Malte',
#    'Moldavie',
#    'Russie',
#    'Slovénie',
#    'Hongrie',
#    'Confédération suisse',
#    'Royaume de Belgique',
#    "République d'Autriche",
#    'Norway',
#    'Spain',
#    'Luxembourg',
#    'Royaume des Pays-Bas']},
#  'Amérique du Nord': {'continentCode': 'NA',
#   'country_codes': ['AG',
#    'AI',
#    'AW',
#    'BB',
#    'BL',
#    'BM',
#    'BQ',
#    'BS',
#    'BZ',
#    'CA',
#    'CR',
#    'CU',
#    'CW',
#    'DM',
#    'DO',
#    'GD',
#    'GL',
#    'GP',
#    'GT',
#    'HN',
#    'HT',
#    'JM',
#    'KN',
#    'KY',
#    'LC',
#    'MF',
#    'MQ',
#    'MS',
#    'MX',
#    'NI',
#    'PA',
#    'PM',
#    'PR',
#    'SV',
#    'SX',
#    'TC',
#    'TT',
#    'US',
#    'VC',
#    'VG',
#    'VI'],
#   'country_code_iso3': ['ATG',
#    'AIA',
#    'ABW',
#    'BRB',
#    'BLM',
#    'BMU',
#    'BES',
#    'BHS',
#    'BLZ',
#    'CAN',
#    'CRI',
#    'CUB',
#    'CUW',
#    'DMA',
#    'DOM',
#    'GRD',
#    'GRL',
#    'GLP',
#    'GTM',
#    'HND',
#    'HTI',
#    'JAM',
#    'KNA',
#    'CYM',
#    'LCA',
#    'MAF',
#    'MTQ',
#    'MSR',
#    'MEX',
#    'NIC',
#    'PAN',
#    'SPM',
#    'PRI',
#    'SLV',
#    'SXM',
#    'TCA',
#    'TTO',
#    'USA',
#    'VCT',
#    'VGB',
#    'VIR'],
#   'country_names': ['Greenland',
#    'Aruba',
#    'Commonwealth de la Dominique',
#    'Barbados',
#    'Belize',
#    'Panama',
#    'Puerto Rico',
#    'Canada',
#    'Jamaica',
#    'Saint Pierre and Miquelon',
#    'United States',
#    'U.S. Virgin Islands',
#    'Nicaragua',
#    'Guadeloupe',
#    'Anguilla',
#    'Bélize',
#    'Honduras',
#    'Mexico',
#    'République de Trinité-et-Tobago',
#    'Trinidad and Tobago',
#    'République du Guatémala',
#    'États-Unis du Mexique',
#    "République d'Haïti",
#    'Grenada',
#    "États-Unis d'Amérique",
#    'République du Costa Rica',
#    'République dominicaine',
#    'Dominicaine (République)',
#    'Dominican Republic',
#    'Curacao',
#    'Saint Lucia',
#    'El Salvador',
#    'Guatemala',
#    'Haïti',
#    'Fédération de Saint-Christophe-et-Niévès',
#    'Cayman Islands',
#    'Costa Rica',
#    'Trinité-et-Tobago',
#    'République du Nicaragua',
#    'Commonwealth des Bahamas',
#    'Cuba',
#    'Mexique',
#    'Barbade',
#    'Sint Maarten',
#    'Saint-Vincent-et-les-Grenadines',
#    'Saint Vincent and the Grenadines',
#    'Dominica',
#    'Grenade',
#    'République de Cuba',
#    'Saint Barthelemy',
#    'République du Panama',
#    'Dominique',
#    'Sainte-Lucie',
#    'Antigua and Barbuda',
#    'Bahamas',
#    'Haiti',
#    'Jamaïque',
#    'Salvador',
#    'Turks and Caicos Islands',
#    'British Virgin Islands',
#    'États-Unis',
#    'Saint Kitts and Nevis',
#    'Bermuda',
#    'Bonaire, Saint Eustatius and Saba ',
#    'Montserrat',
#    'Antigua-et-Barbuda',
#    'Saint-Christophe-et-Niévès',
#    'République du Honduras',
#    'Martinique',
#    'Saint Martin',
#    'Guatémala',
#    'République du Salvador']},
#  'Océanie': {'continentCode': 'OC',
#   'country_codes': ['AU',
#    'CK',
#    'FJ',
#    'FM',
#    'GU',
#    'KI',
#    'MH',
#    'NC',
#    'NF',
#    'NR',
#    'NU',
#    'NZ',
#    'PG',
#    'PN',
#    'PW',
#    'SB',
#    'TK',
#    'TO',
#    'TV',
#    'VU',
#    'WF',
#    'WS'],
#   'country_code_iso3': ['AUS',
#    'COK',
#    'FJI',
#    'FSM',
#    'GUM',
#    'KIR',
#    'MHL',
#    'NCL',
#    'NFK',
#    'NRU',
#    'NIU',
#    'NZL',
#    'PNG',
#    'PCN',
#    'PLW',
#    'SLB',
#    'TKL',
#    'TON',
#    'TUV',
#    'VUT',
#    'WLF',
#    'WSM'],
#   'country_names': ['État indépendant de Papouasie-Nouvelle-Guinée',
#    'Royaume des Tonga',
#    'Nauru',
#    'Pitcairn',
#    'République des Fidji',
#    'Micronésie',
#    'Micronesia',
#    'République du Vanuatu',
#    'Australie',
#    'Norfolk Island',
#    'Guam',
#    'Solomon Islands',
#    'Îles Marshall',
#    'États fédérés de Micronésie',
#    'Marshall (Îles)',
#    'Palau',
#    'République des Kiribati',
#    'Papouasie-Nouvelle-Guinée',
#    'Cook (Îles)',
#    'Îles Cook',
#    'République de Nauru',
#    'Nouvelle-Zélande',
#    'République des Îles Marshall',
#    "Commonwealth d'Australie",
#    'Tonga',
#    'République des Palaos',
#    'New Zealand',
#    'Vanuatu',
#    'Kiribati',
#    'Papua New Guinea',
#    'Samoa',
#    'Palaos',
#    'Salomon',
#    'Îles Salomon',
#    'Tokelau',
#    'Niue',
#    'Tuvalu',
#    'Australia',
#    'Wallis and Futuna',
#    'Fiji',
#    'New Caledonia',
#    'Marshall Islands',
#    'État indépendant des Samoa',
#    'Fidji',
#    'Cook Islands']},
#  'Amérique du Sud': {'continentCode': 'SA',
#   'country_codes': ['BR',
#    'CO',
#    'AR',
#    'PE',
#    'VE',
#    'CL',
#    'EC',
#    'BO',
#    'PY',
#    'UY',
#    'GY',
#    'SR',
#    'GF',
#    'FK'],
#   'country_code_iso3': ['BRA',
#    'COL',
#    'ARG',
#    'PER',
#    'VEN',
#    'CHL',
#    'ECU',
#    'BOL',
#    'PRY',
#    'URY',
#    'GUY',
#    'SUR',
#    'GUF',
#    'FLK'],
#   'country_names': ['Chili',
#    'République du Paraguay',
#    'République du Pérou',
#    'Bolivie',
#    'République coopérative du Guyana',
#    'Brésil',
#    'Peru',
#    'République de Colombie',
#    "République d'Équateur",
#    'Argentina',
#    'République du Chili',
#    "République orientale de l'Uruguay",
#    'État plurinational de Bolivie',
#    'Falkland Islands',
#    'Colombie',
#    'Argentine',
#    'Colombia',
#    'République argentine',
#    'Vénézuéla',
#    'Pérou',
#    'Équateur',
#    'République fédérative du Brésil',
#    'Ecuador',
#    'Suriname',
#    'Chile',
#    'Brazil',
#    'Bolivia',
#    'Guyana',
#    'République du Suriname',
#    'Paraguay',
#    'République bolivarienne du Vénézuéla',
#    'Uruguay',
#    'French Guiana',
#    'Venezuela']},
#  'Antarctique': {'continentCode': 'AN',
#   'country_codes': [],
#   'country_code_iso3': [],
#   'country_names': []}}

# %%
# Final lists for continents and countries

list_countries_fr = [] # contains country names in French and in English

for key in my_continents_fr.keys():
    list_countries_fr+=[string.lower() for string in my_continents_fr[key]['country_names']]

print(list_countries_fr)

list_continents_fr = [key.lower() for key in my_continents_fr.keys()] # continent names in French
print(list_continents_fr)

print(my_continent_codes) # basic dic : code : name
# Out:
# ['benin', 'algérie', 'république togolaise', 'burkina', 'république gabonaise', 'kenya', 'zambia', 'angola', 'guinée-bissao', 'lésotho', 'mauritania', 'république de sierra leone', 'rwanda', 'république du bénin', 'equatorial guinea', 'eswatini', 'royaume du lesotho', "république arabe d'égypte", 'république du mozambique', 'république du soudan', 'république de zambie', 'république de maurice', 'érythrée', 'zambie', 'sudan', 'sao tome and principe', 'république fédérale de somalie', 'egypt', 'gambia', 'djibouti', 'guinée équatoriale', 'maurice', 'zimbabwe', 'éthiopie', 'état de libye', 'république des seychelles', 'mali', 'sénégal', 'république du botswana', 'république du zimbabwé', 'south africa', 'tunisie', 'burkina faso', 'reunion', 'kénya', 'cameroon', 'mauritanie', 'république du kénya', 'république du rwanda', 'maroc', 'république islamique de mauritanie', 'république du ghana', 'république du libéria', 'gambie', 'comoros', 'lesotho', 'union des comores', "république de côte d'ivoire", 'république du burundi', 'eritrea', 'liberia', 'mayotte', 'république de namibie', 'ivory coast', 'république tunisienne', 'botswana', 'malawi', 'république démocratique de sao tomé-et-principe', 'seychelles', 'soudan', 'république du malawi', 'république fédérale du nigéria', 'ethiopia', 'ghana', 'république centrafricaine', "république d'angola", 'république du tchad', 'république unie de tanzanie', 'république de guinée équatoriale', 'mozambique', 'cap-vert', 'république de gambie', 'togo', 'madagascar', "état d'érythrée", 'sao tomé-et-principe', 'libéria', 'guinée', 'république du cap-vert', 'royaume du maroc', "république d'ouganda", 'cameroun', 'république du sénégal', 'guinea-bissau', 'tchad', 'république démocratique du congo', 'guinea', 'ouganda', "royaume d'eswatini", 'comores', 'nigeria', 'république de guinée', "république d'afrique du sud", 'senegal', 'nigéria', 'libya', 'morocco', 'congo (république démocratique du)', 'tunisia', "république démocratique fédérale d'éthiopie", 'tanzanie', 'niger', 'république du congo', 'république algérienne démocratique et populaire', 'zimbabwé', 'burundi', 'république de djibouti', 'tanzania', 'sierra leone', 'centrafrique', 'république du niger', 'bénin', 'gabon', 'central african republic', 'republic of the congo', 'égypte', 'libye', 'algeria', 'south sudan', 'congo', 'namibie', "côte d'ivoire", 'saint helena', 'namibia', 'cabo verde', 'chad', 'somalia', 'république de madagascar', 'république de guinée-bissao', 'afrique du sud', 'mauritius', 'république du mali', 'uganda', 'somalie', 'république du cameroun', 'democratic republic of the congo', 'pakistan', 'south korea', 'tajikistan', 'république populaire de chine', "république d'azerbaïdjan", 'afghanistan', 'république populaire du bangladesh', 'georgia', 'hong kong', 'japan', 'chypre', 'république des maldives', 'jordan', 'république arabe syrienne', 'république islamique du pakistan', 'singapore', 'état du koweït', "république d'arménie", 'république démocratique fédérale du népal', 'république du yémen', 'liban', 'saudi arabia', 'république socialiste du vietnam', 'bhutan', "état d'israël", "république islamique d'iran", 'syria', 'iraq', 'république de corée', 'kirghizstan', 'royaume hachémite de jordanie', 'sri lanka', "république d'ouzbékistan", 'république des philippines', 'royaume de bahreïn', 'inde', 'turquie', 'émirats arabes unis', 'corée du sud', 'timor leste', 'cambodia', 'myanmar', 'république de chypre', 'israel', 'syrie', 'iran', 'république du kazakhstan', 'lebanon', 'india', 'laos', 'république de singapour', 'corée du nord', 'malaysia', 'azerbaïdjan', 'china', "république d'irak", 'royaume de thaïlande', 'turkmenistan', 'bahreïn', 'état du qatar', 'singapour', 'united arab emirates', 'malaisie', 'ouzbékistan', 'kyrgyzstan', 'géorgie', 'brunei darussalam', 'arabie saoudite', 'bahrain', 'irak', 'népal', 'nepal', 'république kirghize', 'israël', 'uzbekistan', 'yémen', 'oman', "république de l'inde", 'turkménistan', 'th ...
# ['afrique', 'asie', 'europe', 'amérique du nord', 'océanie', 'amérique du sud', 'antarctique']

# %%
# utility function : from a list of entities, look for continent names and country names
# store them in a dictionnary

def continent_info(input_list, ref = ['afrique', 'asie', 'europe', 'amérique du nord', 'océanie', 'amérique du sud', 'antarctique', 'amérique']):
    geo_dic={key:[] for key in ['cont', 'country', 'country_code', 'state', 'city', 'misc']}
    for string in set(input_list):
        if string in ref:
            geo_dic['cont'].append(string)
    return geo_dic

def country_info(input_list, ref = list_countries_fr):
    geo_dic={key:[] for key in ['cont', 'country', 'country_code', 'state', 'city', 'misc']}
    for string in set(input_list):
        if string in ref:
            geo_dic['cont'].append(string)
    return geo_dic


print(continent_info(['israël', 'genève', 'new york', 'abou ammar', 'alger', 'israël', 'aviv', 'koweït', 'palestine', 'terre', 'jordanie', 'liban', 'beyrouth', 'syrie', 'israël', 'liban', 'damas', 'jérusalem', 'syrie', 'beyrouth', 'tunis', 'egypte', 'israël', 'syrie', 'damas', 'tripoli', 'iran', 'jordanie', 'egypte', 'palestine', 'israël', 'genève', 'israël', 'rusé', 'habile', 'new york', 'kenya', 'amérique du sud', 'genève', 'israël', 'new york', 'jérusalem', 'diplomatique', 'washington']))
print(continent_info(['afrique', 'asie', 'afrique']))
print(country_info(['israël', 'genève', 'new york', 'abou ammar', 'alger', 'israël', 'aviv', 'koweït', 'palestine', 'terre', 'jordanie', 'liban', 'beyrouth', 'syrie', 'israël', 'liban', 'damas', 'jérusalem', 'syrie', 'beyrouth', 'tunis', 'egypte', 'israël', 'syrie', 'damas', 'tripoli', 'iran', 'jordanie', 'egypte', 'palestine', 'israël', 'genève', 'israël', 'rusé', 'habile', 'new york', 'kenya', 'amérique du sud', 'genève', 'israël', 'new york', 'jérusalem', 'diplomatique', 'washington']))
print(country_info(['afrique', 'asie', 'afrique']))

my_ref_zones = ['afrique', 'asie', 'europe', 'amérique du nord', 'amérique', 'océanie', 'amérique du sud', 'amérique latine', 'antarctique', 'moyen-orient']

def continent_only(input_list, ref = my_ref_zones):
    cont_list=set()
    for string in set(input_list):
        if string in ref:
            cont_list.add(string)
    return cont_list

def country_only(input_list, ref = list_countries_fr):
    country_list=set()
    for string in set(input_list):
        if string in ref:
            country_list.add(string)
    return country_list

print(continent_only(['israël', 'genève', 'new york', 'abou ammar', 'alger', 'israël', 'aviv', 'koweït', 'palestine', 'terre', 'jordanie', 'liban', 'beyrouth', 'syrie', 'israël', 'liban', 'damas', 'jérusalem', 'syrie', 'beyrouth', 'tunis', 'egypte', 'israël', 'syrie', 'damas', 'tripoli', 'iran', 'jordanie', 'egypte', 'palestine', 'israël', 'genève', 'israël', 'rusé', 'habile', 'new york', 'kenya', 'amérique du sud', 'genève', 'israël', 'new york', 'jérusalem', 'diplomatique', 'washington']))
print(continent_only(['afrique', 'asie', 'afrique', 'amérique latine']))
print(country_only(['israël', 'genève', 'new york', 'abou ammar', 'alger', 'israël', 'aviv', 'koweït', 'palestine', 'terre', 'jordanie', 'liban', 'beyrouth', 'syrie', 'israël', 'liban', 'damas', 'jérusalem', 'syrie', 'beyrouth', 'tunis', 'egypte', 'israël', 'syrie', 'damas', 'tripoli', 'iran', 'jordanie', 'egypte', 'palestine', 'israël', 'genève', 'israël', 'rusé', 'habile', 'new york', 'kenya', 'amérique du sud', 'genève', 'israël', 'new york', 'jérusalem', 'diplomatique', 'washington']))
print(country_only(['afrique', 'asie', 'afrique', 'amérique latine']))
# Out:
# {'cont': ['amérique du sud'], 'country': [], 'country_code': [], 'state': [], 'city': [], 'misc': []}
# {'cont': ['afrique', 'asie'], 'country': [], 'country_code': [], 'state': [], 'city': [], 'misc': []}
# {'cont': ['koweït', 'israël', 'syrie', 'jordanie', 'iran', 'kenya', 'liban'], 'country': [], 'country_code': [], 'state': [], 'city': [], 'misc': []}
# {'cont': [], 'country': [], 'country_code': [], 'state': [], 'city': [], 'misc': []}
# {'amérique du sud'}
# {'amérique latine', 'afrique', 'asie'}
# {'koweït', 'israël', 'jordanie', 'iran', 'kenya', 'syrie', 'liban'}
# set()

# %% [markdown]
# ### 1.2 Write utility functions to retrieve info about cities
#
# using geopy

# %%
from geonamescache.mappers import country

iso_to_cont_mapper = country(from_key='iso', to_key='continentcode')

# test
print(my_continent_codes[iso_to_cont_mapper('DE')]) 

print(countries['DE'])
# Out:
# Europe
# {'geonameid': 2921044, 'name': 'Germany', 'iso': 'DE', 'iso3': 'DEU', 'isonumeric': 276, 'fips': 'GM', 'continentcode': 'EU', 'capital': 'Berlin', 'areakm2': 357021, 'population': 81802257, 'tld': '.de', 'currencycode': 'EUR', 'currencyname': 'Euro', 'phone': '49', 'postalcoderegex': '^(\\d{5})$', 'languages': 'de', 'neighbours': 'CH,PL,NL,DK,BE,CZ,LU,FR,AT'}

# %%
def city_info(city_list):
    from geopy.geocoders import Nominatim
    from geopy.exc import GeocoderTimedOut    
    geopy.geocoders.options.default_user_agent = "my-application2"
    geolocator = Nominatim(timeout=2)

    loc_list=[]
    loc_dic = {key:[] for key in ['cont', 'country', 'country_code', 'state', 'city', 'misc']}

    for city in city_list : 
        print('\n', city)
        try:
            location = geolocator.geocode(city, addressdetails=True, language="fr")
            if location:
                print(location.latitude, location.longitude)
                loc_list.append(location)
                
                address = location.raw['address'] 
                print(address)
                
                if len(set(['shop', 'amenity', 'building', 'neighbourhood', 'leisure', 'hamlet', 'locality', 'isolated_dwelling'])&address.keys())>0:
                    pass     # discard the entity because of high probability of mistake           
                    
                elif 'city' in address.keys(): # city, or road in a city
                    loc_dic['misc'].append(address.get('tourism', '').lower() )
                    loc_dic['city'].append(address.get('city', '').lower() )
                    loc_dic['state'].append(address.get('state', '') .lower() )
                    loc_dic['country'].append(address.get('country', '').lower()  )
                    cc = address.get('country_code', '').upper()
                    loc_dic['country_code'].append(cc)
                    loc_dic['cont'].append(my_continent_codes[iso_to_cont_mapper(cc)].lower() )
                elif 'town' in address.keys(): # town, or road in a town 
                    loc_dic['misc'].append(address.get('tourism', '').lower() )
                    loc_dic['city'].append(address.get('town', '').lower()  )                                   
                    loc_dic['state'].append(address.get('state', '') .lower() )
                    loc_dic['country'].append(address.get('country', '').lower()  )
                    cc = address.get('country_code', '').upper()
                    loc_dic['country_code'].append(cc)
                    loc_dic['cont'].append(my_continent_codes[iso_to_cont_mapper(cc)].lower() )
                elif 'road' in address.keys():
                    loc_dic['misc'].append(address.get('road', '').lower() )
                elif 'place' in address.keys():
                    loc_dic['state'].append(address.get('place', '').lower())
                    loc_dic['state'].append(address.get('state', '') .lower() )
                    loc_dic['country'].append(address.get('country', '').lower()  )
                    cc = address.get('country_code', '').upper()
                    loc_dic['country_code'].append(cc)
                    loc_dic['cont'].append(my_continent_codes[iso_to_cont_mapper(cc)].lower() )                    
                elif 'region' in address.keys():
                    loc_dic['state'].append(address.get('region', '').lower())
                    loc_dic['state'].append(address.get('state', '') .lower() )
                    loc_dic['country'].append(address.get('country', '').lower()  )
                    cc = address.get('country_code', '').upper()
                    loc_dic['country_code'].append(cc)
                    loc_dic['cont'].append(my_continent_codes[iso_to_cont_mapper(cc)].lower() )                    
                elif 'village' in address.keys():
                    loc_dic['misc'].append(address.get('tourism', '').lower() )
                    loc_dic['misc'].append(address.get('village', '').lower() )
                    loc_dic['city'].append(address.get('municipality', '').lower()  )
                    loc_dic['state'].append(address.get('state', '') .lower() )
                    loc_dic['country'].append(address.get('country', '').lower()  )
                    cc = address.get('country_code', '').upper()
                    loc_dic['country_code'].append(cc)
                    loc_dic['cont'].append(my_continent_codes[iso_to_cont_mapper(cc)].lower() )                    
                elif 'waterway' in address.keys():
                    loc_dic['misc'].append(address.get('waterway', '').lower() )
                    loc_dic['country'].append(address.get('country', '').lower()  )
                    cc = address.get('country_code', '').upper()
                    loc_dic['country_code'].append(cc)
                    loc_dic['cont'].append(my_continent_codes[iso_to_cont_mapper(cc)].lower() )                                    
                else : # name of a state already, or a "boundary", or a country
                    loc_dic['state'].append(address.get('state', '') .lower() )
                    loc_dic['state'].append(address.get('boundary', '') .lower() ) # region-like zone
                    loc_dic['country'].append(address.get('country', '').lower()  )
                    cc = address.get('country_code', '').upper()
                    loc_dic['country_code'].append(cc)
                    loc_dic['cont'].append(my_continent_codes[iso_to_cont_mapper(cc)].lower() )
                   
        except GeocoderTimedOut as e:
            print("Error: geocode failed on input %s with message %s" %(city, e))
            loc_dic['misc'].append(city.lower())

    loc_dic = {key : set([string for string in loc_dic[key] if len(string)>0]) for key in loc_dic.keys()}
    print('\n---- List of Locations ---')
    print(loc_list)
    print('\n---- Dictionnary ---')
    print(loc_dic)
    return loc_dic

city_list=['Verrières-le-Buisson', "Munich", "Palais de l'Elysée", "Reichstag", 'france', 'la seine', 'cisjordanie', 'bretagne', 'chabot', 'bourgogne', 'boulevard maillot', 
           'trac', 'valium', 'nezvran', 'franc-maçon', 'pr lebreton', 'moyen-orient', 
           'gaza', 'sympathie', 'schultz', 'la terre', 'genou']

test = city_info(city_list)
test
# Out:
#  Verrières-le-Buisson
# 48.7467819 2.2653844
# {'town': 'Verrières-le-Buisson', 'municipality': 'Palaiseau', 'county': 'Essonne', 'state': 'Île-de-France', 'country': 'France', 'postcode': '91370', 'country_code': 'fr'}
#
#  Munich
# 48.1371079 11.5753822
# {'city': 'Munich', 'state': 'Bavière', 'country': 'Allemagne', 'country_code': 'de'}
#
#  Palais de l'Elysée
# 48.87037435 2.316068734550804
# {'tourism': "Palais de l'Élysée", 'road': 'Avenue de Marigny', 'neighbourhood': 'Quartier de la Madeleine', 'suburb': 'Paris 8e Arrondissement', 'city': 'Paris', 'municipality': 'Paris', 'county': 'Paris', 'state': 'Île-de-France', 'country': 'France', 'postcode': '75008', 'country_code': 'fr'}
#
#  Reichstag
# 52.4676201 13.5280284
# {'tourism': 'Reichstag', 'house_number': '81', 'road': 'An der Wuhlheide', 'suburb': 'Oberschöneweide', 'borough': 'Treptow-Köpenick', 'city': 'Berlin', 'district': 'Rixdorf', 'state': 'Berlin', 'postcode': '12459', 'country': 'Allemagne', 'country_code': 'de'}
#
#  france
# 46.603354 1.8883335
# {'country': 'France', 'country_code': 'fr'}
#
#  la seine
# 48.7308806 2.444754
# {'waterway': 'La Seine', 'country': 'France', 'postcode': '78230', 'country_code': 'fr'}
#
#  cisjordanie
# 32.0254688 35.2888075
# {'place': 'Cisjordanie', 'village': 'ترمسعيا', 'county': 'منطقة ب', 'state': 'Judea et Samaria', 'postcode': '63620', 'country': 'Palestinian Territory', 'country_code': 'ps'}
#
#  bretagne
# 48.2640845 -2.9202408
# {'state': 'Bretagne', 'country': 'France', 'country_code': 'fr'}
#
#  chabot
# 45.9557459 3.5723579
# {'hamlet': 'Chabot', 'village': 'Châteldon', 'municipality': 'Thiers', 'county': 'Puy-de-Dôme', 'state': 'Auvergne-Rhône-Alpes', 'country': 'France', 'postcode': '63290', 'country_code': 'fr'}
#
#  bourgogne
# 47.27808725 4.222486304306048
# {'boundary': 'Bourgogne', 'country': 'France', 'country_code': 'fr'}
#
#  boulevard maillot
# 48.8784495 2.2743374
# {'road': 'Boulevard Maillot', 'town': 'Neuilly-sur-Seine', 'municipality': 'Nanterre', 'county': 'Hauts-de-Seine', 'state': 'Île-de-France', 'country': 'France', 'postcode': '92200', 'country_code': 'fr'}
#
#  trac
# 43.8726977 -0.2684811
# {'isolated_dwelling': 'Trac', 'village': 'Perquie', 'municipality': 'Mont-de-Marsan', 'county': 'Landes', 'state': 'Nouvelle-Aquitaine', 'country': 'France', 'postcode': '40190', 'country_code': 'fr'}
#
#  valium
# 41.9671407 22.7773408
# {'amenity': 'Валиум', 'road': 'бул. Македонија', 'suburb': 'Ново Делчево', 'town': 'Делчево', 'municipality': 'Општина Делчево', 'state': "Région de l'Est", 'postcode': '2320', 'country': 'Macédoine du Nord', 'country_code': 'mk'}
#
#  nezvran
#
#  franc-maçon
# 64.1444941 -21.9127324
# {'amenity': 'Franc-maçon', 'house_number': '3', 'road': 'Bríetartún', 'neighbourhood': 'Tún', 'suburb': 'Laugardalur', 'city': 'Reykjavik', 'state_district': 'Höfuðborgarsvæðið', 'postcode': '105', 'country': 'Islande', 'country_code': 'is'}
#
#  pr lebreton
# 49.3347215 -1.6978046
# {'shop': 'Lebreton', 'road': 'Rue Philippe le Bel', 'hamlet': 'La Hieullerie', 'village': 'Portbail', 'city': 'Port-Bail-sur-Mer', 'municipality': 'Cherbourg', 'county': 'Manche', 'state': 'Normandie', 'country': 'France', 'postcode': '50580', 'country_code': 'fr'}
#
#  moyen-orient
# 43.2927845 5.3725024
# {'amenity': 'Le Moyen Orient', 'road': 'Rue de la Paix Marcel Paul', 'quarter': 'Opéra', 'suburb': '1er Arrondissement', 'city': 'Marseille', 'municipality': 'Marseille', 'county': 'Bouches-du-Rhône', 'state': "Provence-Alpes-Côte d'Azur", 'country': 'France', 'postcode': '13001', 'country_code': 'fr'}
#
#  gaza
# 31.4331663 34.3779285
# {'region': 'Bande de Gaza', 'country': 'Palestinian Territory', 'country_code': 'ps'}
#
#  sympathie
# 44.0969405 6.232955593333333
# {'building': 'La Sympathie', 'road': 'Rue Pierre Magnan', 'neighbourhood': 'Les Épinettes', 'town': 'Digne-les-Bains', 'municipality': 'Digne-les-Bains', 'county': 'Alpes-de-Haute-Provence', 'state': "Provence-Alpes-Côte d'Azur", 'country': 'France', 'postcode': '04000', 'country_code': 'fr'}
#
#  schultz
# 42.5805909 -85.3463969
# {'hamlet': 'Schultz', 'municipality': 'Hope Township', 'county': 'Barry County', 'state': 'Michigan', 'country': "États-Unis d'Amérique", 'country_code': 'us'}
#
#  la terre
# 44.7739122 9.6291891
# {'hamlet': 'Le Terre', 'village': 'Bettola', 'county': 'Piacenza', 'state': 'Émilie-Romagne', 'country': 'Italie', 'country_code': 'it'}
#
#  genou
# 48.4106019 6.0681225
# {'locality': 'En Genou', 'village': 'Vaudémont', 'municipality': 'Nancy', 'county': 'Meurthe-et-Moselle', 'state': 'Grand Est', 'country': 'France', 'postcode': '54330', 'country_code': 'fr'}
#
# ---- List of Locations ---
# [Location(Verrières-le-Buisson, Palaiseau, Essonne, Île-de-France, France métropolitaine, 91370, France, (48.7467819, 2.2653844, 0.0)), Location(Munich, Bavière, Allemagne, (48.1371079, 11.5753822, 0.0)), Location(Palais de l'Élysée, Avenue de Marigny, Quartier de la Madeleine, Paris 8e Arrondissement, Paris, Île-de-France, France métropolitaine, 75008, France, (48.87037435, 2.316068734550804, 0.0)), Location(Reichstag, 81, An der Wuhlheide, Oberschöneweide, Treptow-Köpenick, Berlin, Rixdorf, Berlin, 12459, Allemagne, (52.4676201, 13.5280284, 0.0)), Location(France, (46.603354, 1.8883335, 0.0)), Location(La Seine, France métropolitaine, 78230, France, (48.7308806, 2.444754, 0.0)), Location(Cisjordanie, ترمسعيا, منطقة ب, Judea et Samaria, 63620, Palestinian Territory, (32.0254688, 35.2888075, 0.0)), Location(Bretagne, France métropolitaine, France, (48.2640845, -2.9202408, 0.0)), Location(Chabot, Châteldon, Thiers, Puy-de-Dôme, Auvergne-Rhône-Alpes, France métropolitaine, 63290, France, (45.9557459, 3.5723579, 0.0)), Location(Bourgogne, France métropolitaine, France, (47.27808725, 4.222486304306048, 0.0)), Location(Boulevard Maillot, Neuilly-sur-Seine, Nanterre, Hauts-de-Seine, Île-de-France, France métropolitaine, 92200, France, (48.8784495, 2.2743374, 0.0)), Location(Trac, Perquie, Mont-de-Marsan, Landes, Nouvelle-Aquitaine, France métropolitaine, 40190, France, (43.8726977, -0.2684811, 0.0)), Location(Валиум, бул. Македонија, Ново Делчево, Делчево, Општина Делчево, Région de l'Est, 2320, Macédoine du Nord, (41.9671407, 22.7773408, 0.0)), Location(Franc-maçon, 3, Bríetartún, Tún, Laugardalur, Reykjavik, Höfuðborgarsvæðið, 105, Islande, (64.1444941, -21.9127324, 0.0)), Location(Lebreton, Rue Philippe le Bel, La Hieullerie, Portbail, Port-Bail-sur-Mer, Cherbourg, Manche, Normandie, France métropolitaine, 50580, France, (49.3347215, -1.6978046, 0.0)), Location(Le Moyen Orient, Rue de la Paix Marcel Paul, Opéra, 1er Arrondissement, Marseille, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, 13001, France, (43.2927845, 5.3725024, 0.0)), Location(Bande de Gaza, Palestinian Territory, (31.4331663, 34.3779285, 0.0)), Location(La Sympathie, Rue Pierre Magnan, Les Épinettes, Digne-les-Bains, Alpes-de-Haute-Provence, Provence-Alpes-Côte d'Azur, France métropolitaine, 04000, France, (44.0969405, 6.232955593333333, 0.0)), Location(Schultz, Hope Township, Barry County, Michigan, États-Unis d'Amérique, (42.5805909, -85.3463969, 0.0)), Location(Le Terre, Bettola, Piacenza, Émilie-Romagne, Italie, (44.7739122, 9.6291891, 0.0)), Location(En Genou, Vaudémont, Nancy, Meurthe-et-Moselle, Grand Est, France métropolitaine, 54330, France, (48.4106019, 6.0681225, 0.0))]
#
# ---- Dictionnary ---
# {'cont': {'europe', 'asie'}, 'country': {'france', 'palestinian territory', 'allemagne'}, 'country_code': {'PS', 'FR', 'DE'}, 'state': {'bretagne', 'bande de gaza', 'île-de-france', 'cisjordanie', 'berlin', 'judea et samaria', 'bavière', 'bourgogne'}, 'city': {'verrières-le-buisson', 'neuilly-sur-seine', 'berlin', 'munich'}, 'misc': {'la seine', 'reichstag'}}
# {'cont': {'asie', 'europe'},
#  'country': {'allemagne', 'france', 'palestinian territory'},
#  'country_code': {'DE', 'FR', 'PS'},
#  'state': {'bande de gaza',
#   'bavière',
#   'berlin',
#   'bourgogne',
#   'bretagne',
#   'cisjordanie',
#   'judea et samaria',
#   'île-de-france'},
#  'city': {'berlin', 'munich', 'neuilly-sur-seine', 'verrières-le-buisson'},
#  'misc': {'la seine', 'reichstag'}}

# %%
# summary of remaining issues 

city_info(["zorglub", "amérique latine", "mars", "soleil"])
# Out:
#  zorglub
#
#  amérique latine
#
#  mars
# 45.022172 4.3221548
# {'village': 'Mars', 'municipality': 'Tournon-sur-Rhône', 'county': 'Ardèche', 'state': 'Auvergne-Rhône-Alpes', 'country': 'France', 'postcode': '07320', 'country_code': 'fr'}
#
#  soleil
# 46.1178584 5.0808015
# {'hamlet': 'Le Soleil', 'village': 'Saint-André-le-Bouchoux', 'municipality': 'Bourg-en-Bresse', 'county': 'Ain', 'state': 'Auvergne-Rhône-Alpes', 'country': 'France', 'postcode': '01240', 'country_code': 'fr'}
#
# ---- List of Locations ---
# [Location(Mars, Tournon-sur-Rhône, Ardèche, Auvergne-Rhône-Alpes, France métropolitaine, 07320, France, (45.022172, 4.3221548, 0.0)), Location(Le Soleil, Saint-André-le-Bouchoux, Bourg-en-Bresse, Ain, Auvergne-Rhône-Alpes, France métropolitaine, 01240, France, (46.1178584, 5.0808015, 0.0))]
#
# ---- Dictionnary ---
# {'cont': {'europe'}, 'country': {'france'}, 'country_code': {'FR'}, 'state': {'auvergne-rhône-alpes'}, 'city': {'tournon-sur-rhône'}, 'misc': {'mars'}}
# {'cont': {'europe'},
#  'country': {'france'},
#  'country_code': {'FR'},
#  'state': {'auvergne-rhône-alpes'},
#  'city': {'tournon-sur-rhône'},
#  'misc': {'mars'}}

# %% [markdown]
# __Full pipeline__
#
# For getting structured info about geographic locations from a list of extracted entities
#
# 1. continents
# 2. countries
# 3. cities on what remains --> higher level fields are added too
# 4. fusion of sets

# %%
def geo_info(entity_list, ref_cont = my_ref_zones, ref_countries = list_countries_fr): # to add : , **kwargs
    cont_set = continent_only(entity_list, ref=ref_cont)
    country_set = country_only(entity_list, ref=ref_countries)
    city_list = list(set(entity_list)-(cont_set|country_set))
    geo_dico = city_info(city_list)
    geo_dico['cont']=geo_dico['cont']|cont_set
    geo_dico['country']=geo_dico['country']|country_set
    return geo_dico

# test

test = ['amérique latine', 'france', 'paris', 'reichstag', 'mars']

geo_info(test)
# Out:
# {'amérique latine'}
#
#  paris
# 48.8566969 2.3514616
# {'city': 'Paris', 'municipality': 'Paris', 'county': 'Paris', 'state': 'Île-de-France', 'country': 'France', 'country_code': 'fr'}
#
#  reichstag
# 52.4676201 13.5280284
# {'tourism': 'Reichstag', 'house_number': '81', 'road': 'An der Wuhlheide', 'suburb': 'Oberschöneweide', 'borough': 'Treptow-Köpenick', 'city': 'Berlin', 'district': 'Rixdorf', 'state': 'Berlin', 'postcode': '12459', 'country': 'Allemagne', 'country_code': 'de'}
#
#  mars
# 45.022172 4.3221548
# {'village': 'Mars', 'municipality': 'Tournon-sur-Rhône', 'county': 'Ardèche', 'state': 'Auvergne-Rhône-Alpes', 'country': 'France', 'postcode': '07320', 'country_code': 'fr'}
#
# ---- List of Locations ---
# [Location(Paris, Île-de-France, France métropolitaine, France, (48.8566969, 2.3514616, 0.0)), Location(Reichstag, 81, An der Wuhlheide, Oberschöneweide, Treptow-Köpenick, Berlin, Rixdorf, Berlin, 12459, Allemagne, (52.4676201, 13.5280284, 0.0)), Location(Mars, Tournon-sur-Rhône, Ardèche, Auvergne-Rhône-Alpes, France métropolitaine, 07320, France, (45.022172, 4.3221548, 0.0))]
#
# ---- Dictionnary ---
# {'cont': {'europe'}, 'country': {'france', 'allemagne'}, 'country_code': {'FR', 'DE'}, 'state': {'auvergne-rhône-alpes', 'île-de-france', 'berlin'}, 'city': {'tournon-sur-rhône', 'paris', 'berlin'}, 'misc': {'reichstag', 'mars'}}
# {'cont': {'amérique latine', 'europe'},
#  'country': {'allemagne', 'france'},
#  'country_code': {'DE', 'FR'},
#  'state': {'auvergne-rhône-alpes', 'berlin', 'île-de-france'},
#  'city': {'berlin', 'paris', 'tournon-sur-rhône'},
#  'misc': {'mars', 'reichstag'}}

# %% [markdown]
# ### 1.3 Entity Extraction
#
# Using spacy

# %%
# as a function

def entity_extractor(text_series, ent_type='LOC'):
    """
    Input:
    ------
    text_series : pandas series containing strings to process
    ent_type : type of entity to extract, LOC by default
    
    Output:
    ------
    ent_list : list of list of extracted entities, same length as the input text_series
    """
    
    nlp = spacy.load("fr") # reload
    # Create pipe containing all titles
    bodies=list(nlp.pipe(text_series.apply(lambda x: x.lower()), disable=["tagger", "parser"]) ) 
    
    ent_list = []
    for doc in bodies: 
        ent_list.append([ent.text for ent in doc.ents if ent.label_ == ent_type])

    return ent_list

# test
LOC_list = entity_extractor(news_df.text)
print(LOC_list[:10])
# Out:
# [['bourgogne', 'moskova', 'bordeaux', 'chabot', 'de france', 'houston', 'bretagne'], ['forêt de rambouillet', 'république de versailles', 'forêt de rambouillet', 'thiais', 'pr lebreton', 'moelle', 'autopsie', 'versailles', 'perray-en-yvelines', 'yvelines', 'versailles', 'valium', 'contre-autopsie', 'pr lebreton', 'matignon', 'libourne', 'paris', 'hôtel lutétia', 'matignon', 'rue de rivoli', 'etat', 'paris', 'matignon', 'caen', 'gagne', 'de france', 'franc-maçon', 'boulevard maillot', 'montréal', 'royan', 'moyen-orient', 'trac', 'neuilly', 'barsac'], ['chaldean street', 'reagan', 'shultz', 'cisjordanie', 'gaza', 'israël', 'israël', 'amérique', 'israël', 'israël', 'réfléchir', 'israël', 'gaza', 'etat', 'samarie', 'israël', 'israël', 'jérusalem', '»', 'israël', 'etat', 'sympathie', 'israël', 'jérusalem', 'israël'], ['beyrouth', 'jean-paul', 'liban', 'paris', 'val-de-grâce', 'liban', 'bastia', 'téhéran', 'libanais', "côte-d'ivoire", 'boulos ancache', 'bienveillante', 'syrie', 'damas', 'portugal', 'la france', 'beyrouth', 'téhéran', 'paris', 'france'], ['la terre', 'mars', 'arizona'], ['israël', 'genève', 'new york', 'abou ammar', 'alger', 'israël', 'aviv', 'israël', 'palestine', 'jérusalem', 'au caire', 'koweït', 'palestine', 'terre', 'jordanie', 'liban', 'beyrouth', 'syrie', 'israël', 'liban', 'damas', 'jérusalem', 'syrie', 'beyrouth', 'tunis', 'egypte', 'israël', 'syrie', 'damas', 'tripoli', 'iran', 'jordanie', 'egypte', 'palestine', 'israël', 'genève', 'israël', 'rusé', 'habile', 'new york', 'kenya', 'amérique du sud', 'genève', 'israël', 'new york', 'jérusalem', 'diplomatique', 'washington'], ['var', 'séoul', 'los angeles', 'de californie', 'allais', 'los angeles', 'paris', 'relis', 'bol', 'péage-de-roussillon', 'saint-esprit', 'los angeles', 'colombes', 'séoul', 'oubliais', 'los angeles', 'la perche', 'biscotos', 'france', 'genou', 'séoul', 'tranche', 'séoul'], ["l'algérie", 'algérie', 'ouanza', 'annaba', 'tunisie', 'alger', 'alger', 'algériens', 'alger', 'crs algériens', 'état-', 'mostaganem', 'annaba', 'alger', 'etat', 'palais de justice', 'oran', 'tizi ouzou', 'kabylie frondeuse', 'kabylie', 'alger', 'maghreb', 'algérie', 'constantine', 'paris', 'algériens', 'alger', 'blida', 'état'], ['israël', 'gaza', 'cisjordanie', 'israël', 'jordanie', 'interview', 'jérusalem', 'gaza', 'europe', 'etats-unis', 'cisjordanie', 'gaza', 'etats-unis', 'israël', 'cisjordanie', 'gaza', 'israël', 'palestiniens_à', 'cisjordanie', 'israël', 'liban', 'israël'], ['fenouil', 'prêle', 'seine', 'soleil']]

# %% [markdown]
# ### 1.4 Comparison of Geo Dicts
#
# Idea :
# - ensemble comparison using Jaccard similarity
# - weighted sum, according to the concept's position in the geographical hierarchy
#
# In practice:
# - Dice similarity
# - Jaccard similarity
# - coeff de recouvrement --> not suitable because gives top similarity to a singleton containing any element from the other set!
#
# Operations on sets : | for union, & for intersection, – for difference, ^ for symmetric difference.

# %%
def jaccard_sim(set1, set2):
    return len(set1&set2)/len(set1|set2)

def dice_sim(set1, set2):
    return 2*len(set1&set2)/(len(set1)+len(set2))

def recov_coeff(set1, set2):
    return len(set1&set2)/min([len(set1), len(set2)])

# test

set1 = {'Bade-Wurtemberg','Île-de-France', 'Bretagne', 'Guerrero',}

set2 = {'Bade-Wurtemberg','Île-de-France', 'Bavière', 'Berlin', 'Aquitaine', }

set3 = {'Bade-Wurtemberg','Île-de-France', 'Bavière'}

print(jaccard_sim(set1, set2))
print(jaccard_sim(set2, set3))
print(jaccard_sim(set1, set3))

print(dice_sim(set1, set2))
print(dice_sim(set2, set3))
print(dice_sim(set1, set3))

print(recov_coeff(set1, set2))
print(recov_coeff(set2, set3))
print(recov_coeff(set1, set3))
# Out:
# 0.2857142857142857
# 0.6
# 0.4
# 0.4444444444444444
# 0.75
# 0.5714285714285714
# 0.5
# 1.0
# 0.6666666666666666

# %%
def geo_sim(dico1, dico2, weights = {'cont':1, 'country':2, 'state':3, 'city':6, 'misc':1}, similarity=dice_sim):
    """
    Input:
    ------
    dico1 : dict with keys 'cont', 'country','country_code', 'state', 'city', 'misc' 
    dico2 : idem
    similarity : str, 'jaccard or 'dice'
    
    Output:
    ------
    sim : float, similarity score for geographic locations contained in the dictionnaries
    """
            
    dico_sim = dict()
    for key in ['cont', 'country', 'state', 'city', 'misc']:
        dico_sim[key]=similarity(dico1[key], dico2[key])
    
    w_sum = sum(list(weights.values()))
    weights = {key : weights[key]/w_sum for key in weights.keys()}
    
    sim=sum([dico_sim[key]*weights[key] for key in dico_sim.keys()])
    
    return sim
# Out:
# 1.0
# 0.82603550295858
# 0.3710622710622711

# %%
# test 

dico1 = {'cont': {'Amérique du Nord', 'Europe'},
 'country': {'Allemagne', 'France', 'Mexique'},
 'country_code': {'DE', 'FR', 'MX'},
 'state': {'Bade-Wurtemberg',
  'Bavière',
  'Berlin',
  'Bretagne',
  'Guerrero',
  'Île-de-France'},
 'city': {'Acapulco',
  'Berlin',
  'Munich',
  'Paris',
  'Quimper',
  'Stuttgart',
  'Verrières-le-Buisson'},
 'misc': {"Palais de l'Élysée", 'Reichstag'}}

dico2 = {'cont': {'Amérique du Nord', 'Europe', 'Afrique'},
 'country': {'Allemagne', 'France', 'Mexique'},
 'state': {'Bade-Wurtemberg',
  'Bavière',
  'Guerrero',
  'Île-de-France'},
 'city': {'Acapulco',
  'Berlin',
  'Munich',
  'Paris',
  'Stuttgart',
  'Verrières-le-Buisson'},
 'misc': set()}

dico3 = {'cont': { 'Europe', 'Afrique'},
 'country': {'France', 'Union Soviétique'},
 'state': {
  'Île-de-France'},
 'city': {'Stuttgart',
  'Verrières-le-Buisson'},
 'misc': {'station MIR', 'espace'}}

print(geo_sim(dico1, dico1))
print(geo_sim(dico1, dico2))
print(geo_sim(dico1, dico3))

# %% [markdown]
# ## 2. Apply geoparsing to the news articles
#
# using the utility functions defined above

# %%
LOC_stopwords = ['etat', 'état', 'pays', 'continent', 'endroit', 'lieu', 'de france', 'état-', 'major', 'état-major']

def remove_mistakes(input_list, stopwords=LOC_stopwords):
    return [w for w in input_list if w not in stopwords]

# test 

remove_mistakes(['etat', 'usa', 'barbades'])
# Out:
# ['usa', 'barbades']

# %%
# test 1

dic_list=[]
for ent_list in LOC_list[:10]:
    ent_list = remove_mistakes(ent_list)
    geo_dic = geo_info(ent_list)
    dic_list.append(geo_dic)
# Out:
# set()
#
#  houston
# 29.7589382 -95.3676974
# {'city': 'Houston', 'county': 'Harris County', 'state': 'Texas', 'country': "États-Unis d'Amérique", 'country_code': 'us'}
#
#  bretagne
# 48.2640845 -2.9202408
# {'state': 'Bretagne', 'country': 'France', 'country_code': 'fr'}
#
#  chabot
# 45.9557459 3.5723579
# {'hamlet': 'Chabot', 'village': 'Châteldon', 'municipality': 'Thiers', 'county': 'Puy-de-Dôme', 'state': 'Auvergne-Rhône-Alpes', 'country': 'France', 'postcode': '63290', 'country_code': 'fr'}
#
#  moskova
# 55.7504461 37.6174943
# {'city': 'Moscou', 'state': 'Moscou', 'region': 'District fédéral central', 'country': 'Russie', 'country_code': 'ru'}
#
#  bordeaux
# 44.841225 -0.5800364
# {'city': 'Bordeaux', 'municipality': 'Bordeaux', 'county': 'Gironde', 'state': 'Nouvelle-Aquitaine', 'country': 'France', 'country_code': 'fr'}
#
#  bourgogne
# 47.27808725 4.222486304306048
# {'boundary': 'Bourgogne', 'country': 'France', 'country_code': 'fr'}
#
# ---- List of Locations ---
# [Location(Houston, Harris County, Texas, États-Unis d'Amérique, (29.7589382, -95.3676974, 0.0)), Location(Bretagne, France métropolitaine, France, (48.2640845, -2.9202408, 0.0)), Location(Chabot, Châteldon, Thiers, Puy-de-Dôme, Auvergne-Rhône-Alpes, France métropolitaine, 63290, France, (45.9557459, 3.5723579, 0.0)), Location(Moscou, District fédéral central, Russie, (55.7504461, 37.6174943, 0.0)), Location(Bordeaux, Gironde, Nouvelle-Aquitaine, France métropolitaine, France, (44.841225, -0.5800364, 0.0)), Location(Bourgogne, France métropolitaine, France, (47.27808725, 4.222486304306048, 0.0))]
#
# ---- Dictionnary ---
# {'cont': {'europe', 'amérique du nord'}, 'country': {"états-unis d'amérique", 'france', 'russie'}, 'country_code': {'RU', 'FR', 'US'}, 'state': {'bretagne', 'texas', 'moscou', 'nouvelle-aquitaine', 'bourgogne'}, 'city': {'houston', 'bordeaux', 'moscou'}, 'misc': set()}
# {'moyen-orient'}
#
#  boulevard maillot
# 48.8784495 2.2743374
# {'road': 'Boulevard Maillot', 'town': 'Neuilly-sur-Seine', 'municipality': 'Nanterre', 'county': 'Hauts-de-Seine', 'state': 'Île-de-France', 'country': 'France', 'postcode': '92200', 'country_code': 'fr'}
#
#  trac
# 43.8726977 -0.2684811
# {'isolated_dwelling': 'Trac', 'village': 'Perquie', 'municipality': 'Mont-de-Marsan', 'county': 'Landes', 'state': 'Nouvelle-Aquitaine', 'country': 'France', 'postcode': '40190', 'country_code': 'fr'}
#
#  royan
# 45.6245332 -1.0287636
# {'town': 'Royan', 'municipality': 'Rochefort', 'county': 'Charente-Maritime', 'state': 'Nouvelle-Aquitaine', 'country': 'France', 'postcode': '17200', 'country_code': 'fr'}
#
#  libourne
# 44.9133742 -0.2427217
# {'town': 'Libourne', 'municipality': 'Libourne', 'county': 'Gironde', 'state': 'Nouvelle-Aquitaine', 'country': 'France', 'postcode': '33500', 'country_code': 'fr'}
#
#  valium
# 41.9671407 22.7773408
# {'amenity': 'Валиум', 'road': 'бул. Македонија', 'suburb': 'Ново Делчево', 'town': 'Делчево', 'municipality': 'Општина Делчево', 'state': "Région de l'Est", 'postcode': '2320', 'country': 'Macédoine du Nord', 'country_code': 'mk'}
#
#  caen
# 49.1810037 -0.3698915
# {'city': 'Caen', 'municipality': 'Caen', 'county': 'Calvados', 'state': 'Normandie', 'country': 'France', 'postcode': '14000', 'country_code': 'fr'}
#
#  contre-autopsie
#
#  moelle
# 46.1113 3.55824
# {'village': 'Molles', 'municipality': 'Vichy', 'county': 'Allier', 'state': 'Auvergne-Rhône-Alpes', 'country': 'France', 'postcode': '03300', 'country_code': 'fr'}
#
#  barsac
# 44.6043291 -0.323435
# {'village': 'Barsac', 'municipality': 'Langon', 'county': 'Gironde', 'state': 'Nouvelle-Aquitaine', 'country': 'France', 'postcode': '33720', 'country_code': 'fr'}
#
#  franc-maçon
# 64.1444941 -21.9127324
# {'amenity': 'Franc-maçon', 'house_number': '3', 'road': 'Bríetartún', 'neighbourhood': 'Tún', 'suburb': 'Laugardalur', 'city': 'Reykjavik', 'state_district': 'Höfuðborgarsvæðið', 'postcode': '105', 'country': 'Islande', 'country_code': 'is'}
#
#  montréal
# 45.4972159 -73.6103642
# {'city': 'Montréal', 'county': 'Agglomération de Montréal', 'region': 'Montréal (06)', 'state': 'Québec', 'country': 'Canada', 'country_code': 'ca'}
#
#  pr lebreton
# 49.3347215 -1.6978046
# {'shop': 'Lebreton', 'road': 'Rue Philippe le Bel', 'hamlet': 'La Hieullerie', 'village': 'Portbail', 'city': 'Port-Bail-sur-Mer', 'municipality': 'Cherbourg', 'county': 'Manche', 'state': 'Normandie', 'country': 'France', 'postcode': '50580', 'country_code': 'fr'}
#
#  paris
# 48.8566969 2.3514616
# {'city': 'Paris', 'municipality': 'Paris', 'county': 'Paris', 'state': 'Île-de-France', 'country': 'France', 'country_code': 'fr'}
#
#  autopsie
#
#  matignon
# 48.5968982 -2.2922438
# {'village': 'Matignon', 'municipality': 'Dinan', 'county': "Côtes-d'Armor", 'state': 'Bretagne', 'country': 'France', 'postcode': '22550', 'country_code': 'fr'}
#
#  thiais
# 48.7643664 2.391024
# {'town': 'Thiais', 'municipality': "Arrondissement de L'Haÿ-les-Roses", 'county': 'Val-de-Marne', 'state': 'Île-de-France', 'country': 'France', 'postcode': '94320', 'country_code': 'fr'}
#
#  rue de rivoli
# 50.6352627 3.0922514
# {'road': 'Rue de Rivoli', 'suburb': 'Fives', 'city_district': 'Lille', 'city': 'Lille', 'municipality': 'Lille', 'county': 'Nord', 'state': 'Hauts-de-France', 'country': 'France', 'postcode': '59045', 'country_code': 'fr'}
#
#  forêt de rambouillet
# 48.6758342 1.752986
# {'village': 'Poigny-la-Forêt', 'municipality': 'Rambouillet', 'county': 'Yvelines', 'state': 'Île-de-France', 'country': 'France', 'postcode': '78125', 'country_code': 'fr'}
#
#  yvelines
# 48.76203735 1.8871375621264361
# {'county': 'Yvelines', 'state': 'Île-de-France', 'country': 'France', 'country_code': 'fr'}
#
#  hôtel lutétia
# 48.851098449999995 2.3274844535178207
# {'tourism': 'Hôtel Lutétia', 'road': 'Boulevard Raspail', 'neighbourhood': 'Quartier Notre-Dame-des-Champs', 'suburb': 'Paris 6e Arrondissement', 'city': 'Paris', 'municipality': 'Paris', 'county': 'Paris', 'state': 'Île-de-France', 'country': 'France', 'postcode': '75006', 'country_code': 'fr'}
#
#  perray-en-yvelines
# 48.6924665 1.8538535
# {'village': 'Le Perray-en-Yvelines', 'municipality': 'Rambouillet', 'county': 'Yvelines', 'state': 'Île-de-France', 'country': 'France', 'postcode': '78610', 'country_code': 'fr'}
#
#  versailles
# 48.8035403 2.1266886
# {'town': 'Versailles', 'municipality': 'Versailles', 'county': 'Yvelines', 'state': 'Île-de-France', 'country': 'France', 'postcode': '78000', 'country_code': 'fr'}
#
#  république de versailles
# 48.8035403 2.1266886
# {'town': 'Versailles', 'municipality': 'Versailles', 'county': 'Yvelines', 'state': 'Île-de-France', 'country': 'France', 'postcode': '78000', 'country_code': 'fr'}
#
#  neuilly
# 48.9321383 1.4209125
# {'village': 'Neuilly', 'municipality': 'Les Andelys', 'county': 'Eure', 'state': 'Normandie', 'country': 'France', 'postcode': '27730', 'country_code': 'fr'}
#
#  gagne
# 44.964183 3.8498886
# {'waterway': 'La Gagne', 'village': 'Cussac-sur-Loire', 'municipality': 'Le Puy-en-Velay', 'county': 'Haute-Loire', 'state': 'Auvergne-Rhône-Alpes', 'country': 'France', 'postcode': '43370', 'country_code': 'fr'}
#
# ---- List of Locations ---
# [Location(Boulevard Maillot, Neuilly-sur-Seine, Nanterre, Hauts-de-Seine, Île-de-France, France métropolitaine, 92200, France, (48.8784495, 2.2743374, 0.0)), Location(Trac, Perquie, Mont-de-Marsan, Landes, Nouvelle-Aquitaine, France métropolitaine, 40190, France, (43.8726977, -0.2684811, 0.0)), Location(Royan, Rochefort, Charente-Maritime, Nouvelle-Aquitaine, France métropolitaine, 17200, France, (45.6245332, -1.0287636, 0.0)), Location(Libourne, Gironde, Nouvelle-Aquitaine, France métropolitaine, 33500, France, (44.9133742, -0.2427217, 0.0)), Location(Валиум, бул. Македонија, Ново Делчево, Делчево, Општина Делчево, Région de l'Est, 2320, Macédoine du Nord, (41.9671407, 22.7773408, 0.0)), Location(Caen, Calvados, Normandie, France métropolitaine, 14000, France, (49.1810037, -0.3698915, 0.0)), Location(Molles, Vichy, Allier, Auvergne-Rhône-Alpes, France métropolitaine, 03300, France, (46.1113, 3.55824, 0.0)), Location(Barsac, Langon, Gironde, Nouvelle-Aquitaine, France métropolitaine, 33720, France, (44.6043291, -0.323435, 0.0)), Location(Franc-maçon, 3, Bríetartún, Tún, Laugardalur, Reykjavik, Höfuðborgarsvæðið, 105, Islande, (64.1444941, -21.9127324, 0.0)), Location(Montréal, Agglomération de Montréal, Montréal (06), Québec, Canada, (45.4972159, -73.6103642, 0.0)), Location(Lebreton, Rue Philippe le Bel, La Hieullerie, Portbail, Port-Bail-sur-Mer, Cherbourg, Manche, Normandie, France métropolitaine, 50580, France, (49.3347215, -1.6978046, 0.0)), Location(Paris, Île-de-France, France métropolitaine, France, (48.8566969, 2.3514616, 0.0)), Location(Matignon, Dinan, Côtes-d'Armor, Bretagne, France métropolitaine, 22550, France, (48.5968982, -2.2922438, 0.0)), Location(Thiais, Arrondissement de L'Haÿ-les-Roses, Val-de-Marne, Île-de-France, France métropolitaine, 94320, France, (48.7643664, 2.391024, 0.0)), Location(Rue de Rivoli, Fives, Lille, Nord, Hauts-de-France, France métropolitaine, 59045, France, (50.6352627, 3.0922514, 0.0)), Location(Poigny-la-Forêt, Rambouillet, Yvelines, Île-de-France, France métropolitaine, 78125, France, (48.6758342, 1.752986, 0.0)), Location(Yvelines, Île-de-France, France métropolitaine, France, (48.76203735, 1.8871375621264361, 0.0)), Location(Hôtel Lutétia, Boulevard Raspail, Quartier Notre-Dame-des-Champs, Paris 6e Arrondissement, Paris, Île-de-France, France métropolitaine, 75006, France, (48.851098449999995, 2.3274844535178207, 0.0)), Location(Le Perray-en-Yvelines, Rambouillet, Yvelines, Île-de-France, France métropolitaine, 78610, France, (48.6924665, 1.8538535, 0.0)), Location(Versailles, Yvelines, Île-de-France, France métropolitaine, 78000, France, (48.8035403, 2.1266886, 0.0)), Location(Versailles, Yvelines, Île-de-France, France métropolitaine, 78000, France, (48.8035403, 2.1266886, 0.0)), Location(Neuilly, Les Andelys, Eure, Normandie, France métropolitaine, 27730, France, (48.9321383, 1.4209125, 0.0)), Location(La Gagne, Cussac-sur-Loire, Le Puy-en-Velay, Haute-Loire, Auvergne-Rhône-Alpes, France métropolitaine, 43370, France, (44.964183, 3.8498886, 0.0))]
#
# ---- Dictionnary ---
# {'cont': {'europe', 'amérique du nord'}, 'country': {'france', 'canada'}, 'country_code': {'FR', 'CA'}, 'state': {'auvergne-rhône-alpes', 'hauts-de-france', 'bretagne', 'québec', 'île-de-france', 'nouvelle-aquitaine', 'normandie'}, 'city': {'vichy', 'royan', 'libourne', 'neuilly-sur-seine', 'caen', 'le puy-en-velay', 'montréal', 'les andelys', 'versailles', 'paris', 'dinan', 'lille', 'rambouillet', 'langon', 'thiais'}, 'misc': {'poigny-la-forêt', 'le perray-en-yvelines', 'barsac', 'neuilly', 'molles', 'matignon', 'cussac-sur-loire'}}
# {'amérique'}
#
#  sympathie
# 44.0969405 6.232955593333333
# {'building': 'La Sympathie', 'road': 'Rue Pierre Magnan', 'neighbourhood': 'Les Épinettes', 'town': 'Digne-les-Bains', 'municipality': 'Digne-les-Bains', 'county': 'Alpes-de-Haute-Provence', 'state': "Provence-Alpes-Côte d'Azur", 'country': 'France', 'postcode': '04000', 'country_code': 'fr'}
#
#  chaldean street
# 43.7931066 -79.3051282
# {'road': 'Chaldean Street', 'neighbourhood': "L'Amoreaux", 'quarter': 'Scarborough—Agincourt', 'suburb': 'Scarborough', 'city': 'Toronto', 'state_district': 'Golden Horseshoe', 'state': 'Ontario', 'postcode': 'M1W 2A3', 'country': 'Canada', 'country_code': 'ca'}
#
#  réfléchir
#
#  cisjordanie
# 32.0254688 35.2888075
# {'place': 'Cisjordanie', 'village': 'ترمسعيا', 'county': 'منطقة ب', 'state': 'Judea et Samaria', 'postcode': '63620', 'country': 'Palestinian Territory', 'country_code': 'ps'}
#
#  jérusalem
# 31.79592425 35.21198075969497
# {'city': 'Jérusalem', 'state': 'District de Jérusalem', 'country': 'Israël', 'country_code': 'il'}
#
#  »
#
#  shultz
# -25.7993876 -55.0968874
# {'neighbourhood': 'Shultz', 'town': 'Santa Rita', 'state': 'Alto Paraná', 'region': 'Región Oriental', 'postcode': '7540', 'country': 'Paraguay', 'country_code': 'py'}
#
#  samarie
# 27.960059649999998 85.04231178334237
# {'city': 'Samari', 'municipality': 'Maghang', 'county': 'नुवाकोट', 'region': 'वाग्मती प्रदेश', 'country': 'Népal', 'country_code': 'np'}
#
#  reagan
# 31.3458428 -101.5295291
# {'county': 'Reagan County', 'state': 'Texas', 'postcode': '76932', 'country': "États-Unis d'Amérique", 'country_code': 'us'}
#
#  gaza
# 31.4331663 34.3779285
# {'region': 'Bande de Gaza', 'country': 'Palestinian Territory', 'country_code': 'ps'}
#
# ---- List of Locations ---
# [Location(La Sympathie, Rue Pierre Magnan, Les Épinettes, Digne-les-Bains, Alpes-de-Haute-Provence, Provence-Alpes-Côte d'Azur, France métropolitaine, 04000, France, (44.0969405, 6.232955593333333, 0.0)), Location(Chaldean Street, L'Amoreaux, Scarborough—Agincourt, Scarborough, Toronto, Golden Horseshoe, Ontario, M1W 2A3, Canada, (43.7931066, -79.3051282, 0.0)), Location(Cisjordanie, ترمسعيا, منطقة ب, Judea et Samaria, 63620, Palestinian Territory, (32.0254688, 35.2888075, 0.0)), Location(Jérusalem, District de Jérusalem, Israël, (31.79592425, 35.21198075969497, 0.0)), Location(Shultz, Santa Rita, Alto Paraná, Región Oriental, 7540, Paraguay, (-25.7993876, -55.0968874, 0.0)), Location(Samari, Maghang, नुवाकोट, वाग्मती प्रदेश, Népal, (27.960059649999998, 85.04231178334237, 0.0)), Location(Reagan County, Texas, 76932, États-Unis d'Amérique, (31.3458428, -101.5295291, 0.0)), Location(Bande de Gaza, Palestinian Territory, (31.4331663, 34.3779285, 0.0))]
#
# ---- Dictionnary ---
# {'cont': {'amérique du nord', 'asie'}, 'country': {"états-unis d'amérique", 'palestinian territory', 'népal', 'israël'}, 'country_code': {'PS', 'IL', 'US', 'NP'}, 'state': {'bande de gaza', 'texas', 'cisjordanie', 'district de jérusalem', 'judea et samaria'}, 'city': {'samari', 'jérusalem'}, 'misc': set()}
# set()
#
#  côte-d'ivoire
# 7.9897371 -5.5679458
# {'country': 'Côte d’Ivoire', 'country_code': 'ci'}
#
#  damas
# 33.5130695 36.3095814
# {'city': 'Damas', 'state': 'Gouvernorat de Damas', 'postcode': '2277', 'country': 'Syrie', 'country_code': 'sy'}
#
#  boulos ancache
#
#  la france
# 46.603354 1.8883335
# {'country': 'France', 'country_code': 'fr'}
#
#  jean-paul
# 49.9395679 11.5311703
# {'tourism': 'Jean-Paul', 'road': 'Meyernberger Straße', 'suburb': 'Meyernberg', 'city_district': 'Meyernberg', 'town': 'Bayreuth', 'state': 'Bavière', 'postcode': '95447', 'country': 'Allemagne', 'country_code': 'de'}
#
#  val-de-grâce
# 48.84221255 2.343882249183209
# {'neighbourhood': 'Quartier du Val-de-Grâce', 'suburb': 'Paris 5e Arrondissement', 'city': 'Paris', 'municipality': 'Paris', 'county': 'Paris', 'state': 'Île-de-France', 'country': 'France', 'postcode': '75005', 'country_code': 'fr'}
#
#  libanais
# 49.1190578 6.1721988
# {'amenity': 'Le Libanais', 'house_number': '12', 'road': 'Rue Sainte-Marie', 'suburb': 'Nouvelle Ville', 'city': 'Metz', 'municipality': 'Metz', 'county': 'Moselle', 'state': 'Grand Est', 'country': 'France', 'postcode': '57045', 'country_code': 'fr'}
#
#  bastia
# 42.7065505 9.452542
# {'town': 'Bastia', 'municipality': 'Bastia', 'county': 'Haute-Corse', 'state': 'Corse', 'country': 'France', 'country_code': 'fr'}
#
#  paris
# 48.8566969 2.3514616
# {'city': 'Paris', 'municipality': 'Paris', 'county': 'Paris', 'state': 'Île-de-France', 'country': 'France', 'country_code': 'fr'}
#
#  beyrouth
# 33.8959203 35.47843
# {'city': 'Beyrouth', 'state': 'Gouvernorat de Beyrouth', 'country': 'Liban', 'country_code': 'lb'}
#
#  téhéran
# 35.6892523 51.3896004
# {'city': 'Téhéran', 'district': 'بخش مرکزی شهرستان تهران', 'county': 'شهرستان تهران', 'province': 'Téhéran', 'country': 'Iran', 'country_code': 'ir'}
#
#  bienveillante
#
# ---- List of Locations ---
# [Location(Côte d’Ivoire, (7.9897371, -5.5679458, 0.0)), Location(Damas, Gouvernorat de Damas, 2277, Syrie, (33.5130695, 36.3095814, 0.0)), Location(France, (46.603354, 1.8883335, 0.0)), Location(Jean-Paul, Meyernberger Straße, Meyernberg, Bayreuth, Bavière, 95447, Allemagne, (49.9395679, 11.5311703, 0.0)), Location(Quartier du Val-de-Grâce, Paris 5e Arrondissement, Paris, Île-de-France, France métropolitaine, 75005, France, (48.84221255, 2.343882249183209, 0.0)), Location(Le Libanais, 12, Rue Sainte-Marie, Nouvelle Ville, Metz, Moselle, Grand Est, France métropolitaine, 57045, France, (49.1190578, 6.1721988, 0.0)), Location(Bastia, Haute-Corse, Corse, France métropolitaine, France, (42.7065505, 9.452542, 0.0)), Location(Paris, Île-de-France, France métropolitaine, France, (48.8566969, 2.3514616, 0.0)), Location(Beyrouth, Gouvernorat de Beyrouth, Liban, (33.8959203, 35.47843, 0.0)), Location(Téhéran, بخش مرکزی شهرستان تهران, شهرستان تهران, Téhéran, Iran, (35.6892523, 51.3896004, 0.0))]
#
# ---- Dictionnary ---
# {'cont': {'europe', 'afrique', 'asie'}, 'country': {'france', 'côte d’ivoire', 'iran', 'allemagne', 'syrie', 'liban'}, 'country_code': {'FR', 'IR', 'DE', 'LB', 'SY', 'CI'}, 'state': {'gouvernorat de beyrouth', 'île-de-france', 'gouvernorat de damas', 'bavière', 'corse'}, 'city': {'damas', 'bayreuth', 'bastia', 'paris', 'beyrouth', 'téhéran'}, 'misc': {'jean-paul'}}
# set()
#
#  arizona
# 34.395342 -111.7632755
# {'state': 'Arizona', 'country': "États-Unis d'Amérique", 'country_code': 'us'}
#
#  la terre
# 44.7739122 9.6291891
# {'hamlet': 'Le Terre', 'village': 'Bettola', 'county': 'Piacenza', 'state': 'Émilie-Romagne', 'country': 'Italie', 'country_code': 'it'}
#
#  mars
# 45.022172 4.3221548
# {'village': 'Mars', 'municipality': 'Tournon-sur-Rhône', 'county': 'Ardèche', 'state': 'Auvergne-Rhône-Alpes', 'country': 'France', 'postcode': '07320', 'country_code': 'fr'}
#
# ---- List of Locations ---
# [Location(Arizona, États-Unis d'Amérique, (34.395342, -111.7632755, 0.0)), Location(Le Terre, Bettola, Piacenza, Émilie-Romagne, Italie, (44.7739122, 9.6291891, 0.0)), Location(Mars, Tournon-sur-Rhône, Ardèche, Auvergne-Rhône-Alpes, France métropolitaine, 07320, France, (45.022172, 4.3221548, 0.0))]
#
# ---- Dictionnary ---
# {'cont': {'europe', 'amérique du nord'}, 'country': {"états-unis d'amérique", 'france'}, 'country_code': {'FR', 'US'}, 'state': {'auvergne-rhône-alpes', 'arizona'}, 'city': {'tournon-sur-rhône'}, 'misc': {'mars'}}
# {'amérique du sud'}
#
#  terre
# 8.5322391 38.6264712
# {'town': 'Terre', 'state': 'Oromia', 'country': 'Éthiopie', 'country_code': 'et'}
#
#  new york
# 40.7127281 -74.0060152
# {'city': 'New York', 'district': 'Stone Street Historic District', 'state': 'New York', 'country': "États-Unis d'Amérique", 'country_code': 'us'}
#
#  habile
# 13.319335 20.981256
# {'hamlet': 'Habilé', 'state': 'Ouaddaï', 'country': 'Tchad', 'country_code': 'td'}
#
#  washington
# 38.8949924 -77.0365581
# {'city': 'Washington', 'state': 'Washington', 'country': "États-Unis d'Amérique", 'country_code': 'us'}
#
#  au caire
# 47.5793537 6.7376743
# {'locality': 'Au Caire', 'isolated_dwelling': 'Champs Sur la Place', 'city_district': 'Héricourt', 'town': 'Héricourt', 'municipality': 'Lure', 'county': 'Haute-Saône', 'state': 'Bourgogne-Franche-Comté', 'country': 'France', 'postcode': '70400', 'country_code': 'fr'}
#
#  damas
# 33.5130695 36.3095814
# {'city': 'Damas', 'state': 'Gouvernorat de Damas', 'postcode': '2277', 'country': 'Syrie', 'country_code': 'sy'}
#
#  palestine
# 31.94696655 35.27386547291496
# {'boundary': 'Territoires Palestiniens', 'state': 'Judea et Samaria', 'country': 'Palestinian Territory', 'country_code': 'ps'}
#
#  abou ammar
# 30.0010226 31.1885874
# {'road': 'حارة سيد عمار', 'neighbourhood': 'مساكن أبو الفتوح', 'city': 'Gizeh', 'postcode': '12555', 'country': 'Égypte', 'country_code': 'eg'}
#
#  rusé
# 43.8480413 25.9542057
# {'city': 'Roussé', 'municipality': 'Municipalité de Roussé', 'state': 'Oblast de Roussé', 'country': 'Bulgarie', 'country_code': 'bg'}
#
#  genève
# 46.2017559 6.1466014
# {'city': 'Genève', 'state': 'Genève', 'country': 'Suisse', 'country_code': 'ch'}
#
#  jérusalem
# 31.79592425 35.21198075969497
# {'city': 'Jérusalem', 'state': 'District de Jérusalem', 'country': 'Israël', 'country_code': 'il'}
#
#  tripoli
# 32.896672 13.1777923
# {'city': 'Tripoli', 'district': 'سوق الجمعة', 'state': 'Tripoli', 'country': 'Libye', 'country_code': 'ly'}
#
#  aviv
# 32.0961451 34.9514955
# {'suburb': 'אביב', 'city': 'ראש העין', 'county': 'נפת פתח תקווה', 'state': 'District centre', 'postcode': '4853313', 'country': 'Israël', 'country_code': 'il'}
#
#  diplomatique
# 40.39511295 49.84934058451485
# {'amenity': "Académie diplomatique d'Azerbaïdjan", 'house_number': '11', 'road': 'Vaqif prospekti', 'city_district': 'Nərimanov rayonu', 'city': 'Bakou', 'state_district': 'Bakou', 'state': 'Abcheron', 'postcode': '1110', 'country': 'Azerbaïdjan', 'country_code': 'az'}
#
#  alger
# 36.7753606 3.0601882
# {'city': 'Alger', 'town': 'Alger Centre', 'county': "Daïra Sidi M'Hamed", 'state': 'Alger', 'postcode': '16007', 'country': 'Algérie', 'country_code': 'dz'}
#
#  beyrouth
# 33.8959203 35.47843
# {'city': 'Beyrouth', 'state': 'Gouvernorat de Beyrouth', 'country': 'Liban', 'country_code': 'lb'}
#
#  tunis
# 33.8439408 9.400138
# {'country': 'Tunisie', 'country_code': 'tn'}
#
#  egypte
# 26.2540493 29.2675469
# {'country': 'Égypte', 'country_code': 'eg'}
#
# ---- List of Locations ---
# [Location(Terre, Oromia, Éthiopie, (8.5322391, 38.6264712, 0.0)), Location(New York, Stone Street Historic District, New York, États-Unis d'Amérique, (40.7127281, -74.0060152, 0.0)), Location(Habilé, Ouaddaï, Tchad, (13.319335, 20.981256, 0.0)), Location(Washington, États-Unis d'Amérique, (38.8949924, -77.0365581, 0.0)), Location(Au Caire, Champs Sur la Place, Héricourt, Lure, Haute-Saône, Bourgogne-Franche-Comté, France métropolitaine, 70400, France, (47.5793537, 6.7376743, 0.0)), Location(Damas, Gouvernorat de Damas, 2277, Syrie, (33.5130695, 36.3095814, 0.0)), Location(Territoires Palestiniens, Judea et Samaria, Palestinian Territory, (31.94696655, 35.27386547291496, 0.0)), Location(حارة سيد عمار, مساكن أبو الفتوح, Gizeh, 12555, Égypte, (30.0010226, 31.1885874, 0.0)), Location(Roussé, Municipalité de Roussé, Oblast de Roussé, Bulgarie, (43.8480413, 25.9542057, 0.0)), Location(Genève, Suisse, (46.2017559, 6.1466014, 0.0)), Location(Jérusalem, District de Jérusalem, Israël, (31.79592425, 35.21198075969497, 0.0)), Location(Tripoli, سوق الجمعة, Tripoli, Libye, (32.896672, 13.1777923, 0.0)), Location(אביב, ראש העין, נפת פתח תקווה, District centre, 4853313, Israël, (32.0961451, 34.9514955, 0.0)), Location(Académie diplomatique d'Azerbaïdjan, 11, Vaqif prospekti, Nərimanov rayonu, Bakou, Abcheron, 1110, Azerbaïdjan, (40.39511295, 49.84934058451485, 0.0)), Location(Alger, Alger Centre, Daïra Sidi M'Hamed, Alger, 16007, Algérie, (36.7753606, 3.0601882, 0.0)), Location(Beyrouth, Gouvernorat de Beyrouth, Liban, (33.8959203, 35.47843, 0.0)), Location(Tunisie, (33.8439408, 9.400138, 0.0)), Location(Égypte, (26.2540493, 29.2675469, 0.0))]
#
# ---- Dictionnary ---
# {'cont': {'europe', 'amérique du nord', 'afrique', 'asie'}, 'country': {'égypte', "états-unis d'amérique", 'israël', 'suisse', 'algérie', 'palestinian territory', 'bulgarie', 'tunisie', 'libye', 'éthiopie', 'syrie', 'liban'}, 'country_code': {'PS', 'BG', 'DZ', 'LY', 'TN', 'CH', 'ET', 'EG', 'LB', 'SY', 'IL', 'US'}, 'state': {'territoires palestiniens', 'oromia', 'gouvernorat de beyrouth', 'genève', 'judea et samaria', 'oblast de roussé', 'district de jérusalem', 'tripoli', 'gouvernorat de damas', 'new york', 'alger', 'washington', 'district centre'}, 'city': {'terre', 'washington', 'damas', 'ראש העין', 'genève', 'jérusalem', 'tripoli', 'new york', 'alger', 'roussé', 'beyrouth'}, 'misc': set()}
# set()
#
#  relis
# 47.257495 9.1096381
# {'road': 'Relis', 'hamlet': 'Dicken', 'village': 'Kappel', 'county': 'Wahlkreis Toggenburg', 'state': 'Saint-Gall', 'postcode': '9642', 'country': 'Suisse', 'country_code': 'ch'}
#
#  tranche
# 45.1159376 1.2780467
# {'hamlet': 'Tranche', 'village': 'Terrasson-Lavilledieu', 'municipality': 'Sarlat-la-Canéda', 'county': 'Dordogne', 'state': 'Nouvelle-Aquitaine', 'country': 'France', 'postcode': '24120', 'country_code': 'fr'}
#
#  colombes
# 48.922788 2.2543577
# {'town': 'Colombes', 'municipality': 'Nanterre', 'county': 'Hauts-de-Seine', 'state': 'Île-de-France', 'country': 'France', 'postcode': '92700', 'country_code': 'fr'}
#
#  var
# 43.4173592 6.2664620128919
# {'county': 'Var', 'state': "Provence-Alpes-Côte d'Azur", 'country': 'France', 'country_code': 'fr'}
#
#  los angeles
# 34.0536909 -118.242766
# {'city': 'Los Angeles', 'county': 'Los Angeles County', 'state': 'Californie', 'country': "États-Unis d'Amérique", 'country_code': 'us'}
#
#  séoul
# 37.5666791 126.9782914
# {'city': 'Séoul', 'country': 'Corée du Sud', 'country_code': 'kr'}
#
#  paris
# 48.8566969 2.3514616
# {'city': 'Paris', 'municipality': 'Paris', 'county': 'Paris', 'state': 'Île-de-France', 'country': 'France', 'country_code': 'fr'}
#
#  de californie
# 51.9600057 7.6264215
# {'amenity': 'La Californie', 'house_number': '1', 'road': 'Königsstraße', 'neighbourhood': 'Dom', 'suburb': 'Altstadt', 'city_district': 'Münster-Mitte', 'city': 'Münster', 'state': 'Rhénanie-du-Nord-Westphalie', 'postcode': '48143', 'country': 'Allemagne', 'country_code': 'de'}
#
#  biscotos
#
#  genou
# 48.4106019 6.0681225
# {'locality': 'En Genou', 'village': 'Vaudémont', 'municipality': 'Nancy', 'county': 'Meurthe-et-Moselle', 'state': 'Grand Est', 'country': 'France', 'postcode': '54330', 'country_code': 'fr'}
#
#  bol
# 9.0 -74.333333
# {'place': 'Bolívar', 'country': 'Colombie', 'country_code': 'co'}
#
#  saint-esprit
# 45.898371 -73.666077
# {'village': 'Saint-Esprit', 'county': 'Montcalm', 'region': 'Lanaudière', 'state': 'Québec', 'postcode': 'J0K 2L0', 'country': 'Canada', 'country_code': 'ca'}
#
#  péage-de-roussillon
# 45.3732685 4.7961586
# {'village': 'Le Péage-de-Roussillon', 'municipality': 'Vienne', 'county': 'Isère', 'state': 'Auvergne-Rhône-Alpes', 'country': 'France', 'postcode': '38550', 'country_code': 'fr'}
#
#  allais
# 37.2667623 -83.1821168
# {'hamlet': 'Allais', 'town': 'Hazard', 'county': 'Perry County', 'state': 'Kentucky', 'postcode': '41701', 'country': "États-Unis d'Amérique", 'country_code': 'us'}
#
#  la perche
# 46.644866 2.5726883
# {'village': 'La Perche', 'municipality': 'Saint-Amand-Montrond', 'county': 'Cher', 'state': 'Centre-Val de Loire', 'country': 'France', 'postcode': '18200', 'country_code': 'fr'}
#
#  oubliais
#
# ---- List of Locations ---
# [Location(Relis, Dicken, Kappel, Ebnat-Kappel, Wahlkreis Toggenburg, Saint-Gall, 9642, Suisse, (47.257495, 9.1096381, 0.0)), Location(Tranche, Terrasson-Lavilledieu, Sarlat-la-Canéda, Dordogne, Nouvelle-Aquitaine, France métropolitaine, 24120, France, (45.1159376, 1.2780467, 0.0)), Location(Colombes, Nanterre, Hauts-de-Seine, Île-de-France, France métropolitaine, 92700, France, (48.922788, 2.2543577, 0.0)), Location(Var, Provence-Alpes-Côte d'Azur, France métropolitaine, France, (43.4173592, 6.2664620128919, 0.0)), Location(Los Angeles, Los Angeles County, Californie, États-Unis d'Amérique, (34.0536909, -118.242766, 0.0)), Location(Séoul, Corée du Sud, (37.5666791, 126.9782914, 0.0)), Location(Paris, Île-de-France, France métropolitaine, France, (48.8566969, 2.3514616, 0.0)), Location(La Californie, 1, Königsstraße, Dom, Altstadt, Münster-Mitte, Münster, Rhénanie-du-Nord-Westphalie, 48143, Allemagne, (51.9600057, 7.6264215, 0.0)), Location(En Genou, Vaudémont, Nancy, Meurthe-et-Moselle, Grand Est, France métropolitaine, 54330, France, (48.4106019, 6.0681225, 0.0)), Location(Bolívar, Colombie, (9.0, -74.333333, 0.0)), Location(Saint-Esprit, Montcalm, Lanaudière, Québec, J0K 2L0, Canada, (45.898371, -73.666077, 0.0)), Location(Le Péage-de-Roussillon, Vienne, Isère, Auvergne-Rhône-Alpes, France métropolitaine, 38550, France, (45.3732685, 4.7961586, 0.0)), Location(Allais, Hazard, Perry County, Kentucky, 41701, États-Unis d'Amérique, (37.2667623, -83.1821168, 0.0)), Location(La Perche, Saint-Amand-Montrond, Cher, Centre-Val de Loire, France métropolitaine, 18200, France, (46.644866, 2.5726883, 0.0))]
#
# ---- Dictionnary ---
# {'cont': {'europe', 'amérique du nord', 'asie', 'amérique du sud'}, 'country': {"états-unis d'amérique", 'colombie', 'france', 'corée du sud', 'canada'}, 'country_code': {'FR', 'KR', 'CA', 'CO', 'US'}, 'state': {'auvergne-rhône-alpes', 'québec', 'île-de-france', 'californie', "provence-alpes-côte d'azur", 'bolívar', 'centre-val de loire', 'lanaudière'}, 'city': {'saint-amand-montrond', 'colombes', 'vienne', 'los angeles', 'séoul', 'paris'}, 'misc': {'la perche', 'le péage-de-roussillon'}}
# set()
#
#  kabylie
# 45.3080981 0.8355407
# {'hamlet': 'La Kabylie', 'city_district': 'Sorges', 'city': 'Sorges et Ligueux en Périgord', 'municipality': 'Périgueux', 'county': 'Dordogne', 'state': 'Nouvelle-Aquitaine', 'country': 'France', 'country_code': 'fr'}
#
#  algériens
# 36.3950057 3.8872999770958083
# {'leisure': 'Camp Scouts Musulmans Algériens', 'town': 'Bouira', 'county': 'Daïra Bouira', 'state': 'Bouira', 'country': 'Algérie', 'country_code': 'dz'}
#
#  ouanza
# 4.285022 22.34449
# {'village': 'Ouanza-Bilengo', 'state': 'Mbomou', 'country': 'République Centrafricaine', 'country_code': 'cf'}
#
#  annaba
# 36.8982165 7.7549272
# {'city': 'Annaba', 'county': 'Daïra Annaba', 'state': 'Annaba', 'postcode': '23000', 'country': 'Algérie', 'country_code': 'dz'}
#
#  palais de justice
# 47.5894285 1.333323713408308
# {'amenity': 'Palais de Justice', 'road': 'Place de la République', 'town': 'Blois', 'municipality': 'Blois', 'county': 'Loir-et-Cher', 'state': 'Centre-Val de Loire', 'country': 'France', 'postcode': '41000', 'country_code': 'fr'}
#
#  paris
# 48.8566969 2.3514616
# {'city': 'Paris', 'municipality': 'Paris', 'county': 'Paris', 'state': 'Île-de-France', 'country': 'France', 'country_code': 'fr'}
#
#  tizi ouzou
# 36.6816175 4.237186047040007
# {'state': 'Tizi Ouzou', 'country': 'Algérie', 'country_code': 'dz'}
#
#  kabylie frondeuse
#
#  alger
# 36.7753606 3.0601882
# {'city': 'Alger', 'town': 'Alger Centre', 'county': "Daïra Sidi M'Hamed", 'state': 'Alger', 'postcode': '16007', 'country': 'Algérie', 'country_code': 'dz'}
#
#  maghreb
# 33.383472999999995 44.37349342232862
# {'suburb': 'Maghreb', 'municipality': 'البلدية العظمية', 'city': 'Bagdad', 'subdistrict': 'ناحية مرکز قضاء العظمية', 'district': 'قضاء الأعظمية', 'state': 'Bagdad', 'country': 'Irak', 'country_code': 'iq'}
#
#  l'algérie
# 50.354053300000004 3.494327106071429
# {'road': "Place de l'Algérie", 'neighbourhood': 'Chasse-Royale', 'city': 'Valenciennes', 'municipality': 'Valenciennes', 'county': 'Nord', 'state': 'Hauts-de-France', 'country': 'France', 'postcode': '59300', 'country_code': 'fr'}
#
#  constantine
# 36.364519 6.60826
# {'city': 'Constantine', 'county': 'Daïra Constantine', 'state': 'Constantine', 'country': 'Algérie', 'country_code': 'dz'}
#
#  mostaganem
# 36.0026915 0.3686866818796205
# {'state': 'Mostaganem', 'country': 'Algérie', 'country_code': 'dz'}
#
#  crs algériens
#
#  blida
# 36.4701645 2.8287985
# {'city': 'Blida', 'county': 'Daïra Blida', 'state': 'Blida', 'country': 'Algérie', 'country_code': 'dz'}
#
#  oran
# 35.7032751 -0.6492976
# {'city': 'Oran', 'county': 'Daïra Oran', 'state': 'Oran', 'country': 'Algérie', 'country_code': 'dz'}
#
#  état-
# -17.495062349999998 -149.49434610884995
# {'tourism': 'Phare de la Pointe Vénus', 'road': 'Route de la Pointe Vénus', 'neighbourhood': 'Lotissement Villierme', 'town': 'Mahina', 'municipality': 'Îles du Vent', 'archipelago': 'Îles du Vent', 'state': 'Polynésie française', 'postcode': '98709', 'country': 'France', 'country_code': 'fr'}
#
# ---- List of Locations ---
# [Location(La Kabylie, Sorges, Sorges et Ligueux en Périgord, Périgueux, Dordogne, Nouvelle-Aquitaine, France métropolitaine, France, (45.3080981, 0.8355407, 0.0)), Location(Camp Scouts Musulmans Algériens, Bouira, Daïra Bouira, Bouira, Algérie, (36.3950057, 3.8872999770958083, 0.0)), Location(Ouanza-Bilengo, Mbomou, République Centrafricaine, (4.285022, 22.34449, 0.0)), Location(Annaba, Daïra Annaba, Annaba, 23000, Algérie, (36.8982165, 7.7549272, 0.0)), Location(Palais de Justice, Place de la République, Blois, Loir-et-Cher, Centre-Val de Loire, France métropolitaine, 41000, France, (47.5894285, 1.333323713408308, 0.0)), Location(Paris, Île-de-France, France métropolitaine, France, (48.8566969, 2.3514616, 0.0)), Location(Tizi Ouzou, Algérie, (36.6816175, 4.237186047040007, 0.0)), Location(Alger, Alger Centre, Daïra Sidi M'Hamed, Alger, 16007, Algérie, (36.7753606, 3.0601882, 0.0)), Location(Maghreb, البلدية العظمية, Bagdad, ناحية مرکز قضاء العظمية, قضاء الأعظمية, Bagdad, Irak, (33.383472999999995, 44.37349342232862, 0.0)), Location(Place de l'Algérie, Chasse-Royale, Valenciennes, Nord, Hauts-de-France, France métropolitaine, 59300, France, (50.354053300000004, 3.494327106071429, 0.0)), Location(Constantine, Daïra Constantine, Constantine, Algérie, (36.364519, 6.60826, 0.0)), Location(Mostaganem, Algérie, (36.0026915, 0.3686866818796205, 0.0)), Location(Blida, Daïra Blida, Blida, Algérie, (36.4701645, 2.8287985, 0.0)), Location(Oran, Daïra Oran, Oran, Algérie, (35.7032751, -0.6492976, 0.0)), Location(Phare de la Pointe Vénus, Route de la Pointe Vénus, Lotissement Villierme, Mahina, Îles du Vent, Polynésie française, 98709, France, (-17.495062349999998, -149.49434610884995, 0.0))]
#
# ---- Dictionnary ---
# {'cont': {'europe', 'afrique', 'asie'}, 'country': {'république centrafricaine', 'france', 'algérie', 'irak'}, 'country_code': {'DZ', 'CF', 'FR', 'IQ'}, 'state': {'oran', 'bagdad', 'annaba', 'île-de-france', 'constantine', 'mostaganem', 'tizi ouzou', 'blida', 'alger', 'mbomou'}, 'city': {'oran', 'bagdad', 'annaba', 'constantine', 'blida', 'paris', 'alger'}, 'misc': {'ouanza-bilengo'}}
# {'europe'}
#
#  interview
# 44.120605499999996 4.838779035568057
# {'shop': 'Interview', 'road': 'G Monsieur Galant', 'retail': 'Zone Commerciale du Coudoulet', 'suburb': 'Coudoulet Ouest', 'town': 'Orange', 'municipality': 'Carpentras', 'county': 'Vaucluse', 'state': "Provence-Alpes-Côte d'Azur", 'country': 'France', 'postcode': '84100', 'country_code': 'fr'}
#
#  palestiniens_à
#
#  cisjordanie
# 32.0254688 35.2888075
# {'place': 'Cisjordanie', 'village': 'ترمسعيا', 'county': 'منطقة ب', 'state': 'Judea et Samaria', 'postcode': '63620', 'country': 'Palestinian Territory', 'country_code': 'ps'}
#
#  jérusalem
# 31.79592425 35.21198075969497
# {'city': 'Jérusalem', 'state': 'District de Jérusalem', 'country': 'Israël', 'country_code': 'il'}
#
#  etats-unis
# 39.7837304 -100.4458825
# {'country': "États-Unis d'Amérique", 'country_code': 'us'}
#
#  gaza
# 31.4331663 34.3779285
# {'region': 'Bande de Gaza', 'country': 'Palestinian Territory', 'country_code': 'ps'}
#
# ---- List of Locations ---
# [Location(Interview, G Monsieur Galant, Zone Commerciale du Coudoulet, Coudoulet Ouest, Orange, Carpentras, Vaucluse, Provence-Alpes-Côte d'Azur, France métropolitaine, 84100, France, (44.120605499999996, 4.838779035568057, 0.0)), Location(Cisjordanie, ترمسعيا, منطقة ب, Judea et Samaria, 63620, Palestinian Territory, (32.0254688, 35.2888075, 0.0)), Location(Jérusalem, District de Jérusalem, Israël, (31.79592425, 35.21198075969497, 0.0)), Location(États-Unis d'Amérique, (39.7837304, -100.4458825, 0.0)), Location(Bande de Gaza, Palestinian Territory, (31.4331663, 34.3779285, 0.0))]
#
# ---- Dictionnary ---
# {'cont': {'amérique du nord', 'asie'}, 'country': {"états-unis d'amérique", 'palestinian territory', 'israël'}, 'country_code': {'PS', 'IL', 'US'}, 'state': {'district de jérusalem', 'judea et samaria', 'cisjordanie', 'bande de gaza'}, 'city': {'jérusalem'}, 'misc': set()}
# set()
#
#  seine
# 48.7308806 2.444754
# {'waterway': 'La Seine', 'country': 'France', 'postcode': '78230', 'country_code': 'fr'}
#
#  soleil
# 46.1178584 5.0808015
# {'hamlet': 'Le Soleil', 'village': 'Saint-André-le-Bouchoux', 'municipality': 'Bourg-en-Bresse', 'county': 'Ain', 'state': 'Auvergne-Rhône-Alpes', 'country': 'France', 'postcode': '01240', 'country_code': 'fr'}
#
#  prêle
# 56.2937366 26.7266734
# {'town': 'Preiļi', 'county': 'Preiļu novads', 'state': 'Latgale', 'postcode': 'LV-5301', 'country': 'Lettonie', 'country_code': 'lv'}
#
#  fenouil
# 45.1061046 -0.4337924
# {'hamlet': 'Le Fenouil', 'village': 'Civrac-de-Blaye', 'municipality': 'Blaye', 'county': 'Gironde', 'state': 'Nouvelle-Aquitaine', 'country': 'France', 'postcode': '33920', 'country_code': 'fr'}
#
# ---- List of Locations ---
# [Location(La Seine, France métropolitaine, 78230, France, (48.7308806, 2.444754, 0.0)), Location(Le Soleil, Saint-André-le-Bouchoux, Bourg-en-Bresse, Ain, Auvergne-Rhône-Alpes, France métropolitaine, 01240, France, (46.1178584, 5.0808015, 0.0)), Location(Preiļi, Preiļu novads, Latgale, LV-5301, Lettonie, (56.2937366, 26.7266734, 0.0)), Location(Le Fenouil, Civrac-de-Blaye, Blaye, Gironde, Nouvelle-Aquitaine, France métropolitaine, 33920, France, (45.1061046, -0.4337924, 0.0))]
#
# ---- Dictionnary ---
# {'cont': {'europe'}, 'country': {'lettonie', 'france'}, 'country_code': {'FR', 'LV'}, 'state': {'latgale'}, 'city': {'preiļi'}, 'misc': {'la seine'}}

# %%
# test 2 - waterways

dic_list=[]
for ent_list in [['la seine', 'garonne', 'rhône']]:
    geo_dic = geo_info(ent_list)
    dic_list.append(geo_dic)
# Out:
# set()
#
#  la seine
# 48.7308806 2.444754
# {'waterway': 'La Seine', 'country': 'France', 'postcode': '78230', 'country_code': 'fr'}
#
#  garonne
# 44.2161598 0.5195403
# {'waterway': 'La Garonne', 'country': 'France', 'postcode': '33190', 'country_code': 'fr'}
#
#  rhône
# 45.8802348 4.564533629559522
# {'county': 'Rhône', 'state_district': 'Circonscription départementale du Rhône', 'state': 'Auvergne-Rhône-Alpes', 'country': 'France', 'country_code': 'fr'}
#
# ---- List of Locations ---
# [Location(La Seine, France métropolitaine, 78230, France, (48.7308806, 2.444754, 0.0)), Location(La Garonne, France métropolitaine, 33190, France, (44.2161598, 0.5195403, 0.0)), Location(Rhône, Circonscription départementale du Rhône, Auvergne-Rhône-Alpes, France métropolitaine, France, (45.8802348, 4.564533629559522, 0.0))]
#
# ---- Dictionnary ---
# {'cont': {'europe'}, 'country': {'france'}, 'country_code': {'FR'}, 'state': {'auvergne-rhône-alpes'}, 'city': set(), 'misc': {'la seine', 'la garonne'}}

# %% [markdown]
# ## 3. Filter and compare on the basis of geoparsing
#
# Idea :
# * input article, by the user --[geoparsing]--> geo_dico --> dataframe continent/country
# * filter on continents and/or countries
# * compute similarity between the input article and all remaining articles
# * keep k1 best
# * compute text similarity using word embeddings
# * retrieve k2 best for reco
